# %% [markdown]
# # Building a Wor2vec model trained on TV Series subtitles:

# %% [markdown]
# ## Unzip subtitles inside a directory "subs"

# %%
# !mkdir subs
# !unzip how-i-met-your-mother-seventh-season_english-1334377.zip -d subs
# Out:
# mkdir: cannot create directory ‘subs’: File exists
# Archive:  how-i-met-your-mother-seventh-season_english-1334377.zip
# Subscene
#   inflating: subs/How I Met Your Mother S07E01 HDTV.X264-Bzingaz.srt
#   inflating: subs/How I Met Your Mother S07E02 HDTV.X264-Bzingaz.srt
#   inflating: subs/How I Met Your Mother S07E03 HDTV.X264-Bzingaz.srt
#   inflating: subs/How I Met Your Mother S07E04 HDTV.X264-Bzingaz.srt
#   inflating: subs/How I Met Your Mother S07E05 HDTV-DIMENSION.X264-Bzingaz.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E06.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E07.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E08.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E09.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E10.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E11.720p.HDTV.x264-IMMERSE.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E12.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E13.720p.HDTV.x264-IMMERSE.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E14.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/how.i.met.your.mother.s07e15.720p.hdtv.x264-orenji.bak.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E16.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E17.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E18.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E19.HDTV.XviD-2HD.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E20.HDTV.x264-NYCDream.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E21.720p.HDTV.X264-DIMENSION.srt
#   inflating: subs/how.i.met.your.mother.s07e22.720p.hdtv.x264-2hd.srt
#   inflating: subs/How.I.Met.Your.Mother.S07E23E24.720p.HDTV.X264-DIMENSION.srt

# %% [markdown]
# ## install pysrt to read and write ".srt" files

# %%
! pip install --quiet gensim pysrt

# %%
import gensim
import logging
import multiprocessing
import os
import sys
import pysrt
import glob
import nltk

# %% [markdown]
# ## Download necessary packages of NLTK

# %%
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# ## Config Logging messages

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',
                    level=logging.INFO)

# %% [markdown]
# ## Loading texts from files :

# %%
files =  glob.glob("subs/*.srt")

# %%
texts = []
for f in files:
    print('Loading '+f)
    subs = pysrt.open(f, encoding='iso-8859-1')
    for s in subs:
        texts.append(s.text)
# Out:
# Loading subs/How.I.Met.Your.Mother.S07E23E24.720p.HDTV.X264-DIMENSION.srt
# Loading subs/how.i.met.your.mother.s07e15.720p.hdtv.x264-orenji.bak.srt
# Loading subs/How.I.Met.Your.Mother.S07E16.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E11.720p.HDTV.x264-IMMERSE.srt
# Loading subs/How.I.Met.Your.Mother.S07E13.720p.HDTV.x264-IMMERSE.srt
# Loading subs/How.I.Met.Your.Mother.S07E21.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E18.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E20.HDTV.x264-NYCDream.srt
# Loading subs/How I Met Your Mother S07E05 HDTV-DIMENSION.X264-Bzingaz.srt
# Loading subs/How I Met Your Mother S07E04 HDTV.X264-Bzingaz.srt
# Loading subs/How.I.Met.Your.Mother.S07E12.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E06.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How I Met Your Mother S07E03 HDTV.X264-Bzingaz.srt
# Loading subs/How.I.Met.Your.Mother.S07E07.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How I Met Your Mother S07E01 HDTV.X264-Bzingaz.srt
# Loading subs/How.I.Met.Your.Mother.S07E19.HDTV.XviD-2HD.srt
# Loading subs/How I Met Your Mother S07E02 HDTV.X264-Bzingaz.srt
# Loading subs/How.I.Met.Your.Mother.S07E17.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E08.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E09.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E10.720p.HDTV.X264-DIMENSION.srt
# Loading subs/How.I.Met.Your.Mother.S07E14.720p.HDTV.X264-DIMENSION.srt
# Loading subs/how.i.met.your.mother.s07e22.720p.hdtv.x264-2hd.srt

# %%
print("Number of paragraphs is :",len(texts))
# Out:
# Number of paragraphs is : 12208

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
segms = []
for t in texts:
    segms.append(word_tokenize(t))

# %% [markdown]
# ## Removing none alphanumeric words  then we applying the PorterStemmer

# %%
final = []
stemmer = PorterStemmer()

for tokens in segms:
    words = [stemmer.stem(word.lower()) for word in tokens if word.isalpha()]
    print(words[:100])
    final.append(words)
# Out:
# ['narrat', 'i', 'kid', 'when', 'aunt', 'lili', 'i', 'went', 'into', 'labor', 'visit', 'to', 'download']
# ['i', 'marshal', 'wa', 'somewher', 'i', 'slightli', 'inconveni']
# ['i', 'in', 'atlant', 'citi', 'i', 'with', 'uncl', 'barney']
# ['i', 'and', 'drunk', 'to', 'the', 'point', 'of', 'i', 'talk', 'like']
# ['babi', 'come']
# ['papa', 'gon', 'na', 'be', 'am', 'i']
# ['hospit', 'must', 'we', 'get', 'now']
# ['okay', 'there', 'like', 'a', 'wait', 'at', 'the', 'valet', 'stand']
# ['plu', 'we', 'in', 'no', 'shape', 'to', 'drive', 'so', 'a', 'car', 'out']
# ['wait', 'do', 'worri', 'we', 'take', 'a', 'cab', 'to', 'the', 'train', 'station']
# ['man', 'yeah', 'good', 'luck', 'get', 'a', 'cab']
# ['it', 'imposs', 'becaus', 'of', 'the', 'big', 'thing']
# ['narrat', 'i', 'kid', 'for', 'the', 'life', 'of', 'i', 'me', 'i', 'ca', 'rememb']
# ['i', 'what', 'the', 'big', 'thing', 'wa', 'in', 'i', 'atlant', 'citi', 'that']
# ['son', 'i', 'wa', 'it', 'i', 'a', 'cheerlead', 'convent']
# ['narrat', 'i', 'no', 'it', 'wa', 'i', 'a', 'porn']
# ['i', 'convent']
# ['i', 'eh', 'i', 'ca']
# ['we', 'stuck', 'in', 'atlant', 'citi', 'citi', 'of', 'atlant', 'stuck', 'in', 'are', 'we']
# ['font', 'how', 'i', 'met', 'your', 'mother', 'font', 'the', 'magician', 'code', 'origin', 'air', 'date', 'on', 'may', 'font', 'visit', 'to', 'download']
# ['sync', 'correct', 'by', 'font', 'elderman', 'font', 'visit', 'to', 'download']
# ['okay', 'lili', 'it', 'go', 'to', 'be', 'fine']
# ['we', 'are', 'not', 'freak', 'out', 'we', 'are', 'not', 'freak', 'out']
# ['i', 'feel', 'calmer', 'alreadi', 'let', 'get', 'you', 'to', 'the', 'hospit']
# ['oh', 'i', 'ca', 'go', 'yet', 'i', 'talk', 'to', 'sonya']
# ['they', 'wo', 'admit', 'me', 'until', 'my', 'contract']
# ['are', 'four', 'minut', 'apart']
# ['okay', 'well', 'if', 'you', 'do', 'make', 'it', 'in', 'time']
# ['i', 'have', 'got', 'you', 'cover', 'when', 'i', 'wa', 'my', 'father', 'caught', 'me']
# ['kiss', 'a', 'boy', 'so', 'he', 'sent', 'me', 'to', 'our', 'famili', 'ranch']
# ['for', 'foal', 'season', 'onc', 'you', 'see', 'a', 'babi', 'hors']
# ['erupt', 'through', 'that', 'birth', 'canal', 'you', 'stop', 'even', 'touch', 'yourself']
# ['anyway', 'i', 'had', 'skinni', 'arm', 'so', 'i', 'got', 'up', 'there', 'elbow', 'deep']
# ['i', 'lost', 'thi', 'watch', 'birth', 'blacki']
# ['okay', 'stop', 'it', 'i', 'am', 'not', 'a', 'farm', 'anim', 'moo']
# ['oh', 'there', 'we', 'go', 'easi', 'girl', 'sugar', 'cube', 'moan']
# ['oh', 'okay']
# ['ah', 'do', 'worri', 'lil']
# ['some', 'of', 'us', 'know', 'what', 'a', 'woman', 'actual', 'need']
# ['at', 'a', 'time', 'like', 'thi']
# ['pant', 'a', 'labor', 'announc']
# ['ted', 'i', 'a', 'man']
# ['i', 'a', 'woman']
# ['i', 'and', 'their', 'best', 'friend']
# ['i', 'embark', 'on', 'an', 'i', 'incred']
# ['i', 'lili', 'cervix', 'is', 'dilat', 'i', 'and', 'we', 'want', 'you', 'all']
# ['i', 'to', 'be', 'part', 'of', 'it', 'i', 'grand']
# ['you', 'are', 'not', 'send', 'that', 'to', 'anyon', 'ever']
# ['so', 'what', 'i', 'need', 'right', 'now', 'is', 'distract', 'from', 'the', 'pain']
# ['just', 'tell', 'me', 'a', 'stori']
# ['uh', 'what', 'stori', 'i', 'do', 'care', 'anyth']
# ['how', 'about', 'the', 'worst', 'cab', 'ride', 'ever']
# ['homeless', 'guy', 'clean', 'your', 'window', 'for', 'you', 'no']
# ['hey', 'get', 'off', 'my', 'cab']
# ['grunt']
# ['blow', 'land', 'oh', 'oh', 'god']
# ['loud', 'thud', 'oh', 'ah']
# ['ted', 'and', 'robin', 'gasp']
# ['both', 'scream']
# ['scream']
# ['we', 'are', 'not', 'panick', 'we', 'are', 'not', 'panick']
# ['get', 'on', 'all', 'four', 'it', 'widen', 'your', 'hind', 'quarter']
# ['stop', 'it', 'i', 'am', 'not', 'a', 'farm', 'anim']
# ['but', 'give', 'me', 'that', 'sugar', 'cube']
# ['okay', 'listen', 'i', 'am', 'go', 'to', 'get', 'you', 'to', 'that', 'hospit']
# ['or', 'die', 'tri', 'and', 'if', 'i', 'succeed']
# ['i', 'ask', 'onli', 'one', 'thing', 'in', 'return']
# ['let', 'me', 'choos', 'your', 'child', 'middl', 'name']
# ['becaus', 'i', 'have', 'thought', 'up', 'the', 'most', 'awesom', 'name', 'of', 'all', 'time']
# ['what', 'the', 'middl', 'name']
# ['wait', 'for', 'it']
# ['i', 'wait']
# ['wait', 'for', 'it']
# ['i', 'said', 'i', 'wait']
# ['wait', 'for', 'it', 'what', 'the', 'middl', 'name']
# ['no', 'the', 'middl', 'name', 'is', 'wait', 'for', 'it']
# ['let', 'say', 'hi', 'first', 'name', 'is', 'oh', 'i', 'do', 'know', 'barney']
# ['he', 'be', 'barney', 'wait', 'for', 'it', 'eriksen']
# ['how', 'awesom', 'is', 'that']
# ['that', 'is']
# ['the', 'coolest', 'middl', 'name', 'of', 'all', 'time']
# ['i', 'know', 'okay', 'listen']
# ['i', 'have', 'a', 'plan', 'to', 'get', 'us', 'to', 'new', 'york']
# ['all', 'we', 'have', 'to', 'do', 'is', 'get', 'our', 'hand', 'on', 'that', 'motorcycl']
# ['and', 'i', 'know', 'just', 'the', 'way', 'to', 'do', 'it']
# ['both', 'sigh']
# ['phone', 'ring']
# ['here']
# ['oh', 'hi', 'judi']
# ['oh', 'good', 'you', 'got', 'the', 'from', 'ted']
# ['no', 'i', 'am', 'not', 'worri', 'my', 'citi', 'hip', 'are', 'too', 'narrow']
# ['your', 'go', 'to', 'get', 'stuck']
# ['i', 'got', 'to', 'go']
# ['i', 'thought', 'you', 'delet', 'that', 'stupid']
# ['okay', 'i', 'sent', 'it', 'by', 'accid']
# ['she', 'like', 'it', 'ye']
# ['just', 'keep', 'tell', 'me', 'stori']
# ['okay', 'okay', 'i', 'got', 'one', 'for', 'you', 'second', 'base', 'with', 'neil', 'young']
# ['um', 'chuckl']
# ['i', 'do', 'normal', 'go', 'to', 'um', 'second', 'base', 'and', 'tell']
# ['but', 'i', 'just', 'spent', 'a', 'magic', 'night', 'with', 'neil', 'young']
# ['whisper', 'he', 'still', 'in', 'my', 'room']
# ['serious', 'oh', 'my', 'god']
# ['be', 'quiet', 'do', 'scare', 'him', 'off']
# ['clear', 'throat']
# []
# ['robin', 'yeah']
# ['that', 'not', 'neil', 'young']
# ['oh', 'god']
# ['both', 'laugh']
# ['oh', 'we', 'bust', 'appl', 'bag', 'i', 'can', 'bust', 'appl', 'bag']
# ['ted', 'rememb', 'when', 'we', 'were', 'date', 'and', 'we', 'threw', 'that', 'parti']
# ['and', 'one', 'of', 'those', 'appet', 'just', 'did', 'sit', 'right']
# ['ah', 'doe', 'sound', 'familiar']
# ['i', 'call', 'thi', 'stori', 'ted', 'and', 'the', 'cuban', 'sandwich', 'crisi']
# ['i', 'toilet', 'flush']
# ['robin', 'i', 'ted', 'came', 'out', 'of', 'that', 'i', 'bathroom', 'look', 'like']
# ['i', 'joe', 'frazier', 'after', 'i', 'the', 'thrilla', 'in']
# ['oh', 'what', 'is', 'that', 'smell']
# ['ugh']
# ['so', 'i', 'be', 'a', 'great', 'girlfriend', 'i', 'tri', 'to', 'help', 'him']
# ['you', 'guy', 'are', 'all', 'crazi', 'i', 'do', 'smell', 'anyth']
# ['anyway', 'uh', 'who', 'want', 'to', 'go', 'up', 'on', 'the', 'roof']
# ['robin', 'i', 'but', 'then']
# ['she', 'who', 'deni', 'it', 'suppli', 'it']
# ['yeah', 'must', 'have', 'been', 'that', 'cuban', 'sandwich', 'huh', 'babe']
# ['both', 'chuckl']
# ['that', 'wa', 'not', 'cool', 'ted']
# ['contract']
# ['that', 'wa', 'cool', 'ted']
# ['grunt', 'just', 'keep', 'go', 'with', 'the', 'stori']
# ['i', 'do', 'even', 'care', 'if', 'i', 'heard', 'it', 'befor']
# ['just', 'tell', 'me', 'uh', 'where', 'doe', 'that', 'door', 'go']
# ['okay']
# ['hey', 'i', 'never', 'notic', 'that', 'door', 'befor']
# ['i', 'wonder', 'where', 'it', 'goe']
# ['ted', 'ted']
# ['no', 'no', 'no', 'let', 'him', 'let', 'him']
# ['wow']
# ['do', 'no']
# ['robi']
# ['oh']
# ['wow']
# ['i', 'cell', 'phone', 'ring']
# ['dad', 'oh', 'good']
# ['let', 'me', 'guess', 'you', 'got', 'ted']
# ['i', 'on', 'my', 'way', 'princess', 'dad', 'wait', 'no', 'not']
# ['damn', 'it', 'ted']
# ['i', 'wa', 'okay', 'with', 'you', 'my', 'aunt', 'my', 'cousin']
# ['and', 'your', 'cousin', 'and', 'the', 'guy', 'that', 'robin', 'thought', 'wa', 'neil', 'young']
# ['but', 'my', 'father', 'is', 'the', 'absolut', 'worst', 'person', 'to', 'have', 'around']
# ['in', 'ani', 'sort', 'of', 'medic', 'situat']
# ['lili', 'i', 'when', 'i', 'wa', 'seven', 'i', 'need']
# ['i', 'to', 'have', 'my', 'tonsil']
# ['daddi', 'i', 'scare']
# ['aw', 'princess', 'i', 'would', 'be', 'too', 'i', 'research', 'thi', 'surgeri']
# ['anyth', 'can', 'happen', 'you', 'could', 'bleed', 'to', 'death']
# ['you', 'could', 'have', 'your', 'jaw', 'remov', 'due', 'to', 'infect']
# ['and', 'the', 'anesthesia', 'could', 'suddenli', 'just', 'stop', 'work']
# ['much', 'like', 'your', 'and', 'my', 'marriag']
# ['laugh']
# ['you', 'do', 'know', 'that', 'get', 'a', 'divor']
# ['do', 'worri', 'about', 'it', 'we', 'talk', 'about', 'it', 'after', 'the', 'surgeri']
# ['calm', 'down', 'girl', 'pant']
# ['okay', 'for', 'the', 'last', 'time', 'i', 'am', 'not']
# ['actual', 'keep', 'go']
# ['okay', 'i', 'admit', 'the', 'whole', 'win', 'a', 'motorcycl', 'plan', 'wa', 'stupid']
# ['especi', 'becaus', 'we', 'been', 'play', 'on', 'the', 'wrong', 'machin']
# ['barney', 'new', 'plan']
# ['meet', 'me', 'at', 'the', 'entranc', 'in', 'five', 'minut']
# ['engin', 'rev']
# ['hop', 'on', 'marshal', 'tonight', 'we', 'ride']
# ['you', 'won', 'that']
# ['not', 'exactli', 'you', 'see', 'i']
# ['get', 'off', 'grunt']
# ['i', 'hope', 'marshal', 'close', 'cube', 'me']
# ['i', 'on', 'my', 'way', 'lili', 'pad']
# ['narrat', 'i', 'kid', 'your', 'uncl', 'marshal']
# ['i', 'ha', 'face', 'mani', 'challeng', 'i', 'in', 'hi']
# ['i', 'but', 'he', 'still', 'consid', 'i', 'get', 'up', 'these', 'two', 'step']
# ['i', 'when', 'he', 'wa', 'thi', 'drunk', 'to', 'be', 'i', 'the', 'hardest', 'one', 'of']
# ['tell', 'me', 'a', 'marshal', 'stori', 'i', 'miss', 'him']
# ['got', 'it', 'the', 'tale', 'of', 'the', 'curs', 'pant']
# ['hey', 'guy', 'chuckl']
# ['so', 'i', 'start', 'worri', 'about', 'these', 'pant']
# ['start', 'to']
# ['no', 'ever', 'sinc', 'i', 'got', 'them', 'terribl', 'thing']
# ['have', 'been', 'happen', 'to', 'me', 'i', 'stub', 'my', 'toe']
# ['i', 'miss', 'my', 'train', 'you', 'put', 'on', 'the', 'pant']
# ['all', 'chuckl', 'and', 'then', 'the', 'ladi', 'at', 'the', 'thrift', 'store', 'said', 'that', 'for', 'year']
# ['no', 'one', 'so', 'much', 'as', 'tri', 'them', 'on', 'can', 'you', 'believ', 'that']
# ['ye']
# ['you', 'know', 'what', 'thi', 'mean']
# ['these', 'pant', 'are', 'curs']
# ['what', 'thi', 'in', 'the', 'pocket']
# ['a', 'clue']
# ['ted', 'i', 'marshal', 'had', 'i', 'the', 'write']
# ['i', 'it', 'led', 'him', 'deep', 'i', 'into', 'the', 'heart', 'of']
# ['gasp', 'it', 'is', 'you']
# ['the', 'one', 'ha', 'arriv']
# ['dri', 'clean']
# ['i', 'rememb', 'that', 'suit', 'he', 'look', 'like']
# ['a', 'littl', 'kid', 'imaginari', 'friend', 'chuckl']
# ['where', 'is', 'he']
# ['narrat', 'i', 'now', 'uncl', 'marshal', 'i', 'knew', 'he', 'had', 'onli', 'one', 'chanc']
# ['i', 'of', 'get', 'out', 'i', 'of', 'atlant', 'citi']
# ['i', 'bribe', 'a', 'cab']
# ['machin', 'that', 'give', 'money']
# ['chuckl']
# ['narrat', 'i', 'now', 'marshal', 'i', 'wa', 'pretti', 'drunk']
# ['i', 'but', 'he', 'swear', 'the', 'atm', 'i', 'start', 'to', 'do']
# ['video', 'game', 'sound', 'effect']
# ['beep']
# ['laugh']
# ['autom', 'voic', 'stop', 'hit', 'me', 'just', 'for', 'that']
# ['you', 'never', 'get', 'home', 'for', 'the', 'birth', 'of', 'your', 'son']
# ['shred', 'sound']
# ['no']
# ['what', 'up', 'bro']
# ['wait', 'how', 'did', 'you', 'with', 'the', 'secur']
# ['i', 'explain']
# ['grunt']
# ['tell', 'me', 'whi', 'we', 'call', 'the', 'author']
# ['right', 'now', 'go', 'ahead', 'call']
# ['but', 'first', 'can', 'you', 'show', 'me', 'the', 'rule', 'that', 'say', 'you', 'ca']
# ['drive', 'a', 'motorcycl', 'on', 'the', 'casino', 'floor']
# ['chuckl']
# ['it', 'not', 'in', 'here']
# ['narrat', 'i', 'and', 'kid', 'that', 'sign', 'i', 'is', 'still', 'there', 'to', 'thi']
# ['when', 'i', 'came', 'out', 'i', 'ran', 'into', 'thi', 'guy']
# ['two', 'seat', 'just', 'open', 'up']
# ['on', 'hi', 'bu', 'to', 'new', 'york']
# ['barney', 'you', 'a', 'geniu']
# ['plu', 'here', 'the', 'best', 'part']
# ['thi', 'quinn', 'thing', 'is', 'probabl', 'done', 'so', 'i', 'basic', 'singl']
# ['he', 'said', 'the', 'bu', 'is', 'full', 'of', 'hot', 'colleg', 'senior']
# ['okay', 'mayb', 'he', 'say', 'colleg']
# ['or', 'hot']
# ['i', 'miss', 'quinn']
# ['groan']
# ['what', 'is', 'take', 'marshal', 'so', 'long']
# ['salt', 'lick']
# ['just', 'finish', 'the', 'door', 'stori']
# ['oh', 'wow']
# ['i', 'do', 'like', 'thi']
# ['groan', 'okay', 'okay', 'four', 'minut']
# ['we', 'go', 'to', 'the', 'hospit']
# ['but', 'not', 'here', 'yet']
# ['i', 'ca', 'go', 'to', 'the', 'hospit', 'without', 'marshal']
# ['i', 'on', 'it', 'lili', 'spread', 'your', 'leg']
# ['i', 'gon', 'na', 'see', 'if', 'we', 'can', 'see', 'the', 'hoov']
# ['uh', 'snout', 'uh', 'the', 'head']
# ['here', 'we', 'go', 'take', 'me', 'to', 'the', 'hospit', 'now']
# ['okay', 'come', 'on', 'come', 'on']
# ['excus', 'me', 'sir']
# ['my', 'wife', 'is', 'in', 'labor', 'and', 'i', 'realli', 'need', 'to']
# ['get', 'to', 'saint', 'marcu', 'hospit']
# ['so', 'where', 'exactli', 'in', 'new', 'york', 'doe', 'thi', 'bu', 'drop', 'off']
# ['buffalo']
# ['what', 'do', 'you', 'mean', 'i', 'ca', 'have', 'an', 'epidur']
# ['you', 'too', 'far', 'along']
# ['thing', 'are', 'move', 'much', 'faster', 'than', 'expect']
# ['look', 'if', 'your', 'hand', 'are', 'tie', 'medic']
# ['just', 'leav', 'the', 'epidur', 'on', 'the', 'tabl', 'and', 'walk', 'away']
# ['do', 'worri']
# ['the', 'babi', 'slide', 'right', 'out', 'huh']
# ['it', 'like', 'a', 'whoosh', 'chuckl']
# ['like', 'a', 'waterslid']
# ['scream']
# ['slightli', 'pain', 'waterslid']
# ['sob']
# ['tell', 'me', 'a', 'stori', 'now']
# ['uh', 'uh']
# ['oh', 'rememb', 'the', 'time', 'barney']
# ['tri', 'to', 'pick', 'up', 'girl', 'as', 'the', 'termin']
# ['ye']
# []
# ['ã', 'la', 'schwarzenegg', 'come', 'with', 'me', 'if', 'you', 'want', 'to', 'bang']
# ['anoth']
# ['oh', 'uh', 'ted', 'and', 'the', 'freakishli', 'long', 'arm', 'hair']
# ['no', 'i', 'disagre', 'becaus', 'the', 'fill']
# ['it', 'depend', 'on', 'what', 'you', 'eat', 'right']
# ['if', 'it']
# ['whoa', 'what', 'the']
# ['robin', 'and', 'marshal', 'whoa']
# ['groan', 'the', 'debunk', 'of', 'the', 'freakishli', 'long', 'arm', 'hair']
# ['wait', 'just', 'a', 'thread']
# ['i', 'wa', 'jealou', 'okay']
# ['barney', 'get', 'all', 'the', 'attent', 'today']
# ['with', 'thi', 'termin', 'thing']
# ['huh', 'ca', 'believ', 'i', 'not', 'get', 'laid', 'in', 'thi', 'thing']
# ['mayb', 'i', 'need', 'to', 'pick', 'a', 'differ', 'part', 'of', 'the', 'movi']
# []
# ['scream']
# ['tell', 'me', 'anoth', 'stori']
# ['oh', 'hey', 'we', 'never', 'finish', 'where', 'doe', 'that', 'door', 'go']
# ['come', 'on']
# ['let', 'check', 'it', 'out']
# ['you', 'know', 'what', 'babi', 'they', 'gone']
# ['it', 'time', 'for', 'us', 'to', 'move', 'on']
# []
# ['oh', 'my', 'god']
# ['scream']
# ['new', 'stori']
# ['uh', 'the', 'time', 'we', 'test']
# ['if', 'banana', 'peel', 'are', 'realli', 'slipperi']
# ['ye']
# ['readi']
# ['there', 'no', 'way', 'that', 'realli', 'slipperi']
# ['grunt']
# ['ow', 'ow', 'ow']
# ['uh', 'the', 'halloween', 'we', 'decid', 'to', 'go', 'as', 'the', 'breakfast', 'club']
# ['but', 'fail', 'to', 'coordin', 'our', 'costum']
# ['uh', 'doe']
# ['oh', 'groan']
# ['sigh']
# ['realli', 'i', 'mean', 'you', 'live', 'with', 'me', 'lili']
# ['yeah', 'that', 'wa', 'funni']
# ['keep', 'go']
# ['oh', 'uh', 'uh']
# ['time', 'barney', 'save', 'a', 'woman', 'life']
# ['readi']
# ['there', 'no', 'way', 'that', 'realli', 'slipperi']
# ['grunt']
# ['scream']
# ['uh', 'the', 'time', 'lili', 'went', 'into', 'labor']
# ['that', 'now']
# ['sorri', 'i', 'run', 'out', 'of', 'stori']
# ['forget', 'it']
# ['they', 'not', 'work', 'anymor']
# ['okay', 'lili', 'i', 'know', 'thi', 'is', 'how', 'you', 'imagin', 'it']
# ['but', 'i', 'want', 'you', 'to', 'know']
# ['that', 'i', 'am', 'here', 'for', 'you', 'and', 'i', 'am', 'rock', 'solid']
# ['oh', 'i', 'can', 'see', 'it', 'head']
# ['oh', 'thank', 'god', 'sonya']
# ['you']
# ['get', 'that', 'thing', 'out', 'of', 'my', 'deliveri', 'room']
# ['weak', 'women', 'disgust', 'me']
# ['all', 'right', 'lili', 'leg', 'up']
# ['we', 'push', 'now', 'ye']
# ['i', 'ca', 'marshal', 'not', 'here', 'yet']
# ['lili']
# ['if', 'you', 'do', 'push', 'i', 'will', 'shove', 'that', 'babi']
# ['up', 'your', 'throat', 'and', 'pull', 'it', 'out', 'of', 'your', 'mouth']
# ['scream']
# ['where', 'the', 'hell', 'is', 'marshal']
# ['i', 'ca', 'do', 'thi', 'without', 'marshal']
# ['narrat', 'i', 'kid', 'sometim', 'the', 'univers', 'i', 'send', 'exactli', 'what', 'you', 'ask']
# ['i', 'other', 'time', 'i', 'it', 'send', 'lili']
# ['groan', 'oh']
# ['rememb', 'the', 'time', 'you', 'had', 'your', 'tonsil', 'out']
# ['yeah', 'yeah']
# ['you', 'scare', 'the', 'crap', 'out', 'of', 'me']
# ['ye', 'i', 'did', 'did', 'i']
# ['laugh']
# ['oh', 'my']
# ['but', 'do', 'you', 'rememb', 'what', 'happen', 'next']
# ['and', 'do', 'worri', 'princess']
# ['if', 'you', 'perman', 'lose', 'the', 'abil', 'to', 'speak']
# ['we', 'give', 'you', 'a', 'chalkboard']
# ['you', 'can', 'hang', 'it', 'around', 'your', 'neck', 'on', 'a', 'littl', 'string']
# ['nurs', 'i', 'do', 'know', 'who', 'thi', 'strang', 'man', 'is']
# ['secur']
# ['what', 'are', 'you', 'talk', 'about', 'i', 'your', 'daddi']
# ['what', 'do', 'you', 'mean']
# ['hey', 'fella', 'come', 'on']
# ['i', 'woke', 'up', 'in', 'a', 'dumpster', 'of', 'medic', 'wast']
# ['and', 'i', 'have', 'been', 'prouder']
# ['becaus', 'much', 'like', 'that', 'dumpster']
# ['you', 'had', 'a', 'lot', 'of', 'gut']
# ['and', 'you', 'use', 'that', 'braveri', 'everi', 'day', 'of', 'your', 'life']
# ['with', 'or', 'without', 'marshal']
# ['you', 'have', 'thi', 'babi']
# ['thank', 'dad']
# ['that', 'stori', 'actual', 'help']
# ['oh', 'good', 'i', 'glad']
# ['and', 'you', 'know', 'few', 'women', 'have', 'vagin', 'tear', 'sever', 'enough']
# ['to', 'need', 'surgic', 'reconstruct']
# ['secur', 'oh', 'come', 'on']
# ['that', 'not', 'necessari']
# ['sweetheart', 'pleas']
# ['oh', 'fella', 'come', 'on']
# ['pleas', 'sir', 'all', 'you', 'have', 'to', 'do']
# ['is', 'take', 'the', 'next', 'exit', 'to', 'manhattan']
# ['you', 'be', 'back', 'on', 'the', 'road', 'in', 'minut']
# ['i', 'alreadi', 'told', 'you']
# ['i', 'not', 'allow', 'to', 'stop']
# ['sir', 'thi', 'man', 'is', 'have', 'a', 'babi', 'tonight']
# ['and', 'instead', 'of', 'go', 'to', 'saint', 'marcu', 'hospit']
# ['we', 'go', 'to', 'buffalo']
# ['and', 'i', 'seen', 'women', 'from', 'there', 'the', 'citi', 'aptli', 'name']
# ['look', 'i', 'a', 'screwup']
# ['i', 'had', 'someth', 'special', 'with', 'thi', 'girl', 'quinn']
# ['and', 'i', 'ruin', 'it']
# ['but', 'thi', 'guy', 'he', 'done', 'everyth', 'right']
# ['he', 'been', 'love', 'and', 'devot', 'sinc', 'he', 'wa', 'year', 'old']
# ['there', 'are', 'onli', 'a', 'few', 'truli', 'great', 'peopl', 'on', 'thi', 'planet']
# ['and', 'he', 'is', 'one', 'of', 'them']
# ['he', 'deserv', 'to', 'be', 'at', 'the', 'birth', 'of', 'hi', 'son']
# ['so', 'what', 'do', 'you', 'say']
# ['unless', 'there', 'an', 'emerg', 'i', 'not', 'allow', 'to', 'stop']
# ['so', 'sit', 'down', 'watch', 'i', 'cocoon', 'and', 'shut', 'up']
# ['i', 'sorri', 'buddi', 'i', 'tri']
# ['narrat', 'i', 'and', 'then', 'someth', 'i', 'wonder']
# ['i', 'have', 'a', 'heart', 'attack']
# ['i', 'have', 'a', 'heart', 'attack']
# ['i', 'have', 'a', 'heart', 'attack']
# ['and', 'my', 'doctor', 'is', 'at', 'saint', 'marcu', 'hospit']
# ['man', 'so', 'is', 'mine']
# ['mine', 'too']
# ['and', 'my', 'son', 'is', 'head', 'of', 'cardiolog']
# ['all', 'we', 'know']
# ['push']
# ['i', 'wish', 'marshal', 'were', 'here']
# ['pant', 'i', 'here', 'babi']
# ['marshal']
# ['i', 'do', 'know', 'whi', 'i', 'pass', 'out']
# ['i', 'have', 'deliv', 'perfectli', 'healthi', 'babi']
# ['and', 'one', 'of', 'them', 'wa', 'even', 'human']
# ['well', 'it', 'differ', 'when', 'it', 'someon', 'you', 'love']
# ['when', 'that', 'head', 'wa', 'come', 'out', 'of', 'your', 'best', 'friend']
# ['oh', 'stop', 'i', 'feel', 'woozi', 'again']
# ['do']
# ['salt', 'lick']
# ['in', 'return', 'for', 'him', 'get', 'me', 'here', 'i', 'may', 'have', 'promis', 'barney']
# ['that', 'our', 'son', 'middl', 'name', 'will', 'be', 'wait', 'for', 'it']
# ['i', 'ca', 'wait', 'just', 'what', 'is', 'the', 'name']
# ['the', 'name', 'is', 'wait', 'for', 'it']
# ['scream']
# ['that', 'is', 'the', 'coolest', 'middl', 'name', 'of', 'all', 'time']
# ['look', 'um']
# ['i', 'know', 'thing', 'have', 'been', 'weird', 'between', 'us', 'the', 'last', 'few', 'month']
# ['but']
# ['marshal', 'and', 'lili', 'are', 'have', 'a', 'babi']
# ['yeah']
# ['and', 'you', 'know', 'i', 'want', 'thi', 'babi', 'to', 'be', 'born']
# ['into', 'a', 'world', 'where', 'we', 'okay']
# ['so', 'friend']
# ['i', 'love', 'you', 'robin']
# ['kid']
# ['you']
# ['friend', 'you']
# ['both', 'laugh']
# ['guy', 'great', 'news', 'from', 'down', 'the', 'hall']
# ['one', 'dollar', 'two', 'bag', 'of', 'gummi', 'bear']
# ['it', 'like', 'i', 'do', 'even', 'care']
# ['what', 'happen', 'for', 'the', 'rest', 'of', 'the', 'day']
# ['i']
# ['hey']
# ['well', 'guy', 'uh']
# ['sigh']
# ['i', 'a', 'dad']
# ['laugh', 'oh', 'my', 'god']
# ['cheer']
# ['everybodi']
# ['thi', 'is', 'marvin']
# ['we', 'name', 'him', 'after', 'my', 'pop']
# ['tell', 'them', 'the', 'full', 'name']
# ['marvin', 'wait', 'for', 'it', 'eriksen']
# ['that', 'is', 'the', 'coolest', 'middl', 'name', 'of']
# ['total']
# ['you', 'were', 'born', 'into', 'a', 'strang', 'world']
# ['like', 'a', 'candl', 'you', 'were', 'meant', 'to', 'share', 'the', 'fire']
# ['i', 'do', 'know', 'where', 'we', 'come', 'from', 'i', 'do', 'know', 'where', 'we', 'go']
# ['but', 'my', 'arm', 'were', 'made', 'to', 'hold', 'you']
# ['so', 'i', 'will', 'never', 'let', 'you', 'go']
# ['you', 'were', 'born']
# ['to', 'chang', 'thi', 'life', 'you', 'were', 'born']
# ['font', 'how', 'i', 'met', 'your', 'mother', 'font', 'the', 'magician', 'code', 'origin', 'air', 'date', 'on', 'may']
# ['exhal']
# ['sync', 'correct', 'by', 'font', 'elderman']
# ['all', 'boo', 'scream']
# ['narrat', 'i', 'which', 'bring', 'us', 'to', 'the', 'stori']
# ['i', 'of', 'a', 'wed', 'day', 'i', 'that', 'went', 'horribl']
# ['ted', 'the', 'bride', 'want', 'to', 'see', 'you']
# ['i', 'uncl', 'barney', 'i', 'wa', 'get']
# ['how', 'the', 'hell', 'did', 'we', 'get', 'there']
# ['i', 'love', 'the', 'name', 'marvin']
# ['marv']
# ['sound', 'like', 'a', 'littl', 'man']
# ['chuckl']
# ['golf', 'next', 'weekend', 'marv']
# ['how', 'that', 'tax', 'report', 'come', 'marv']
# ['at', 'your', 'age', 'erectil', 'dysfunct']
# ['is', 'noth', 'to', 'be', 'asham', 'of', 'marv']
# ['i', 'it', 'wa', 'a', 'beauti']
# ['i', 'but', 'then', 'a', 'thought', 'pop', 'i', 'into', 'my', 'head']
# ['the', 'same', 'thought', 'that', 'will', 'pop', 'i', 'into', 'your', 'head']
# ['i', 'the', 'first', 'time', 'you', 'see', 'your', 'i', 'best', 'friend', 'hold', 'their']
# ['stapl', 'gun', 'click']
# ['wonder', 'how', 'much', 'thi', 'would', 'hurt']
# ['chuckl']
# ['stapl', 'gun', 'click']
# ['scream']
# ['i', 'that', 'guy', 'a']
# ['scream']
# ['babi', 'cri']
# ['oh', 'i', 'think', 'he', 'hungri']
# ['oh', 'we', 'give', 'you', 'some', 'privaci']
# ['wow', 'see', 'them', 'in', 'there', 'all', 'togeth', 'like', 'that']
# ['they', 'a', 'famili', 'you', 'know']
# ['that', 'what', 'i', 'want']
# ['oh', 'ted', 'i', 'glad', 'we', 'friend', 'again']
# ['me', 'too']
# ['becaus', 'as', 'your', 'friend', 'i', 'have', 'to', 'tell', 'you']
# ['you', 'full', 'of', 'crap']
# ['you', 'say', 'you', 'want', 'a', 'famili']
# ['you', 'say', 'you', 'want', 'to', 'meet', 'the', 'one']
# ['but', 'you', 'are', 'alway', 'chase', 'the', 'wrong', 'women']
# ['that', 'is', 'not', 'true']
# ['look', 'at', 'the', 'women', 'you', 'date']
# ['start', 'with', 'me']
# ['i', 'told', 'you', 'right', 'away', 'i', 'did', 'want', 'marriag', 'or', 'kid']
# ['stella', 'had', 'a', 'child', 'with', 'anoth', 'man', 'who', 'she', 'still', 'love']
# ['zoey', 'wa', 'marri', 'and', 'tri', 'to', 'sabotag', 'your', 'career']
# ['and', 'wore', 'a', 'lot', 'of', 'stupid', 'hat']
# ['if', 'you', 'realli', 'want', 'a', 'famili']
# ['you', 'would', 'stop', 'pursu', 'women']
# ['you', 'know', 'that', 'there', 'is', 'no', 'futur', 'with']
# ['okay', 'first', 'of', 'all', 'hat', 'were', 'in', 'that', 'year', 'kind', 'of']
# ['secondli', 'i', 'alway', 'choos', 'women']
# ['there', 'no', 'futur', 'with', 'kind', 'of']
# ['name', 'one', 'except']
# ['victoria']
# ['ted', 'i', 'victoria', 'wa']
# ['exactli', 'and', 'you', 'threw', 'it', 'all', 'away']
# ['to', 'chase', 'after', 'some', 'hot', 'piec', 'of', 'ass', 'scoff']
# ['you', 'mean', 'you', 'thank', 'you']
# ['victoria', 'is', 'the', 'onli', 'woman', 'you', 'date']
# ['who', 'could', 'been', 'the', 'one']
# ['you', 'should', 'call', 'her']
# ['tini', 'thing', 'last', 'time', 'i', 'saw', 'her', 'she', 'wa', 'get', 'engag']
# ['that', 'wa', 'eight', 'month', 'ago']
# ['for', 'all', 'you', 'know', 'she', 'singl', 'again']
# ['what', 'if', 'she', 'marri']
# ['what', 'if', 'she', 'not']
# ['then', 'you', 'would', 'actual', 'have', 'a', 'chanc']
# ['to', 'get', 'what', 'you', 'say', 'you', 'want', 'and', 'it', 'terrifi', 'you']
# ['whi', 'becaus', 'if', 'i', 'stole', 'a', 'scalpel', 'and', 'i', 'cut', 'you', 'open']
# ['all', 'i', 'would', 'find', 'insid', 'is', 'a', 'scare', 'trembl', 'pile', 'of', 'crap']
# ['see', 'i', 'miss', 'these', 'talk']
# ['oh', 'me', 'too']
# ['yeah', 'whoa']
# ['what', 'wrong', 'sigh']
# ['i', 'ruin', 'thing', 'with', 'quinn']
# ['i', 'insist', 'she', 'stop', 'strip']
# ['we', 'got', 'in', 'a', 'huge', 'fight', 'about', 'it']
# ['then', 'i', 'ran', 'off', 'to', 'atlant', 'citi', 'for', 'two', 'day', 'without', 'call']
# ['what', 'the', 'hell', 'am', 'i', 'come', 'home', 'to']
# ['let', 'have', 'an', 'with', 'my', 'six', 'hottest', 'stripper', 'friend']
# ['um', 'how', 'is', 'that', 'a', 'punish']
# ['wait', 'for', 'it']
# ['but', 'i', 'forbid', 'you', 'from', 'film', 'it']
# ['with', 'your', 'overhead', 'camera']
# ['that', 'zoom', 'in', 'on', 'whoever', 'be', 'the', 'loudest']
# ['nooooo']
# ['shudder', 'no', 'that', 'too', 'cruel']
# ['or', 'you', 'know', 'mayb', 'quinn', 'move', 'out']
# ['i', 'did', 'even', 'think', 'of', 'that']
# ['sigh']
# ['hi']
# ['welcom', 'home']
# ['i', 'decid', 'the', 'place', 'wa', 'a', 'bit', 'too', 'american', 'psycho', 'for', 'me']
# ['so', 'while', 'you', 'were', 'gone', 'i', 'hire', 'a', 'decor']
# ['and', 'i', 'ask', 'him']
# ['what', 'would', 'the', 'insid']
# ['of', 'tinkerbel', 'vagina', 'look', 'like']
# ['and', 'the', 'kid', 'just', 'ran', 'with', 'it']
# ['so', 'what', 'do', 'you', 'think']
# ['thank', 'god', 'you', 'still', 'here']
# ['welcom', 'home']
# ['narrat', 'i', 'lili', 'and', 'marshal', 'ask', 'robin', 'i', 'to', 'be', 'the', 'photograph']
# ['i', 'for', 'babi', 'marvin', 'i', 'birth', 'announc', 'card']
# ['i', 'instead', 'of']
# ['i']
# ['i', 'the', 'onli', 'problem']
# ['camera', 'snap']
# ['these', 'are', 'terribl', 'robin']
# ['hey', 'it', 'is', 'not', 'easi', 'get', 'a', 'good', 'shot']
# ['coop', 'up', 'in', 'thi', 'apart']
# ['see', 'two', 'differ', 'style']
# ['i', 'make', 'composit', 'robin', 'make', 'excus']
# ['click']
# ['photo', 'burn']
# ['okay', 'how', 'about', 'thi']
# ['tomorrow', 'we', 'go', 'to', 'central', 'park', 'at', 'sunset']
# ['and', 'we', 'get', 'the', 'perfect', 'pictur', 'in', 'the', 'perfect', 'set']
# ['oh', 'i', 'like', 'that']
# ['it', 'be', 'marvin', 'first', 'outing', 'into', 'the', 'world']
# ['you', 'gon', 'na', 'love', 'the', 'park', 'buddi']
# ['it', 'a', 'great', 'place', 'to', 'meet', 'chick']
# ['dude']
# ['or', 'both']
# ['oh', 'we', 'love', 'you', 'no', 'matter', 'what']
# ['narrat', 'i', 'and', 'kid', 'as', 'i', 'watch', 'your', 'i', 'aunt', 'lili', 'hold', 'her', 'babi', 'boy']
# ['i', 'anoth', 'thought', 'i', 'pop', 'into', 'my']
# ['even', 'though', 'you', 'did', 'buy', 'anyth']
# ['i', 'want', 'to', 'thank', 'you', 'for', 'come', 'in']
# ['here', 'a', 'free', 'teddi', 'bear']
# ['what', 'are', 'you', 'gon', 'na', 'name', 'the', 'littl', 'guy']
# ['six', 'pack']
# ['gun', 'it', 'bitch']
# ['engin', 'rev']
# ['narrat', 'i', 'that', 'girl', 'a', 'mom']
# ['engin', 'rev']
# ['phone', 'chime']
# ['okay', 'so', 'i', 'met', 'thi', 'girl', 'on', 'the', 'train']
# ['and', 'i', 'text', 'her', 'what', 'up']
# ['she', 'text', 'hey', 'exclam', 'point']
# ['doe', 'that', 'mean', 'ask', 'me', 'out', 'or', 'just']
# ['ted', 'we', 'are', 'respons', 'for', 'a', 'whole', 'other', 'human', 'life', 'now']
# ['so', 'new', 'rule', 'you', 'ca', 'come', 'to', 'us', 'with', 'ani', 'issu', 'unless']
# ['it', 'an', 'or', 'higher']
# ['got', 'it']
# ['so', 'i', 'think', 'of', 'text', 'back', 'a', 'winki', 'smiley', 'face']
# ['eight', 'or', 'higher', 'bro']
# ['well', 'no', 'what', 'should', 'i']
# ['eight', 'or', 'higher', 'bro']
# ['no', 'yeah', 'i', 'just', 'wonder', 'if']
# ['eight', 'or', 'higher', 'bro']
# ['well', 'where', 'do', 'you', 'rate', 'thi']
# ['thi', 'is', 'the', 'same', 'as', 'what', 'in', 'littl', 'marvin', 'pant', 'right', 'now']
# ['a', 'soft', 'two']
# ['sorri', 'bro']
# ['stop', 'text', 'the', 'bimbo', 'and', 'call', 'victoria']
# ['that', 'chapter', 'over']
# ['just', 'were', 'destin', 'to', 'be', 'togeth']
# ['destin', 'are', 'you', 'tire', 'of', 'wait', 'for', 'destini', 'ted']
# ['is', 'it', 'time', 'to', 'make', 'your', 'own', 'destini']
# ['hey', 'fals', 'alarm']
# ['what', 'i', 'wa', 'smell', 'wa', 'the', 'previou', 'poop']
# ['which', 'appar', 'is', 'still', 'somewher', 'on', 'my']
# ['cloth', 'in', 'my', 'hair']
# ['hold', 'him', 'would', 'you', 'oh', 'here']
# ['ooh', 'yeah', 'smart']
# ['shutter', 'click']
# ['oh', 'sure', 'that', 'one', 'turn', 'out', 'great', 'ugh']
# ['narrat', 'and', 'then', 'anoth', 'thought', 'pop', 'i', 'into', 'my', 'head']
# ['i', 'that', 'guy', 'nowher', 'i', 'near', 'be', 'a']
# ['line', 'ring']
# ['victoria', 'hello']
# ['hey', 'victoria', 'it', 'ted']
# ['um', 'listen', 'i', 'wa', 'just', 'wonder']
# ['if', 'you', 'want', 'to', 'catch', 'up', 'sometim', 'it', 'been', 'a', 'while']
# ['that', 'sound', 'nice']
# ['i', 'actual', 'around', 'thi', 'afternoon']
# ['oh', 'wow', 'uh', 'great']
# ['maclaren', 'at']
# ['is', 'okay']
# ['i', 'might', 'have', 'a', 'thing', 'later']
# ['yeah', 'yeah', 'see', 'you', 'then']
# ['see', 'you', 'then']
# ['narrat', 'i', 'meanwhil', 'barney', 'i', 'and', 'quinn', 'were', 'off', 'to', 'hawaii']
# ['i', 'for', 'their', 'first', 'getaway', 'i', 'as', 'a']
# ['i', 'need', 'you', 'to', 'open', 'your', 'suitcas']
# ['sigh', 'it', 'mine']
# ['did', 'you', 'have', 'to', 'replac', 'my', 'luggag', 'too']
# ['run', 'away', 'on', 'me', 'again', 'be', 'wear', 'hot', 'pink', 'stiletto']
# ['what', 'that']
# ['yeah', 'what', 'is', 'that']
# ['it', 'a', 'magic', 'trick']
# ['you', 'see', 'i', 'someth', 'of', 'a', 'magician']
# ['open', 'the', 'box', 'sir']
# ['laugh', 'oh', 'i', 'ca', 'do', 'that']
# ['bark']
# ['sir', 'are', 'there', 'drug', 'in', 'that', 'box']
# ['oh', 'no', 'he', 'probabl', 'just', 'bark']
# ['becaus', 'of', 'the', 'explos']
# ['gasp', 'oh', 'my', 'god']
# ['tell', 'us', 'in', 'the', 'box', 'right', 'now']
# ['i', 'ca']
# ['magician', 'code']
# ['ted', 'i', 'okay', 'i', 'need', 'to', 'figur', 'out', 'i', 'if', 'victoria', 'ever', 'got']
# ['i', 'i', 'have', 'to', 'veri', 'subtli', 'i', 'check', 'for', 'an', 'engag']
# ['i', 'hmm', 'ca', 'see', 'the', 'left']
# ['open', 'the', 'box', 'now']
# ['i', 'ca']
# ['magician', 'code']
# ['what', 'the', 'hell', 'is', 'the', 'magician', 'code']
# ['a', 'magician', 'never', 'reveal', 'hi', 'trick']
# ['flanagan', 'my', 'magic', 'mentor']
# ['from', 'the', 'hallow', 'staten', 'island', 'mall', 'magic', 'shop']
# ['taught', 'me', 'the', 'import', 'of', 'the', 'code']
# ['one', 'fate', 'autumn', 'night', 'in']
# ['alway', 'good', 'to', 'tell', 'a', 'long', 'stori', 'while', 'peopl']
# ['are', 'aim', 'gun', 'at', 'you']
# ['wa', 'a', 'night', 'which', 'would', 'chang', 'my', 'life']
# ['thud']
# ['hello', 'flanagan']
# ['are', 'you', 'do', 'here']
# ['um', 'i', 'check', 'up', 'on', 'you']
# ['just', 'to', 'make', 'sure', 'you', 'practic', 'your', 'craft']
# ['or', 'whatev']
# ['that', 'is', 'an', 'honor', 'sir']
# ['and', 'yeah', 'i', 'promis', 'i', 'practic']
# ['but', 'wait']
# ['whi', 'were', 'you', 'whi', 'were', 'you', 'go', 'in', 'my', 'mom', 'room']
# ['uh', 'your', 'mom', 'actual', 'help', 'me', 'with', 'a', 'new', 'trick']
# ['that', 'is', 'so', 'cool']
# ['what', 'is', 'thi', 'trick']
# ['is', 'it', 'saw', 'a', 'ladi', 'in', 'half']
# ['wri', 'chuckl']
# ['well', 'not', 'saw']
# ['but', 'actual']
# ['the', 'magician', 'code', 'forbid', 'me']
# ['from', 'tell', 'you', 'anyth', 'els', 'about', 'the', 'trick']
# ['loretta', 'wayn', 'come', 'back', 'to', 'bed']
# ['okay', 'it', 'involv', 'a', 'bed']
# ['can', 'you', 'at', 'least']
# ['tell', 'me', 'the', 'name', 'of', 'thi', 'trick']
# ['sure', 'kid']
# ['it', 'call']
# ['the', 'disappear', 'salami']
# ['flanagan', 'wife', 'shot', 'him']
# ['befor', 'he', 'could', 'ever', 'tell', 'me', 'what', 'the', 'trick', 'wa']
# ['yeah', 'that', 'guy', 'wa', 'bang', 'your', 'mom']
# ['yup']
# ['total']
# ['flanagan', 'wa', 'not', 'ban']
# ['oh', 'my', 'god', 'he', 'wa']
# ['wait', 'whi', 'are', 'you', 'bring', 'a', 'magic', 'trick', 'to', 'hawaii', 'anyway']
# ['i', 'wa', 'hope', 'to', 'shoot', 'up', 'to', 'honolulu']
# ['for', 'the', 'worldwid', 'magic', 'convent']
# ['do', 'worri', 'notic', 'i', 'wa', 'gone']
# ['it', 'onli', 'three', 'day']
# ['so', 'on', 'our', 'romant', 'getaway']
# ['to', 'help', 'me', 'forget', 'about', 'you', 'skip', 'town', 'on', 'me']
# ['you', 'skip', 'town', 'on', 'me']
# ['look', 'quinn', 'veri', 'import', 'to', 'me']
# ['but', 'you', 'share', 'my', 'heart', 'with', 'an', 'equal', 'import', 'miss']
# ['miss']
# ['direct']
# ['what']
# ['h']
# ['shoot', 'him']
# ['so', 'what', 'did', 'you', 'order']
# ['oh', 'just', 'black', 'coffe']
# ['i', 'like', 'it', 'that', 'way', 'too']
# ['yeah', 'it', 'just', 'tast', 'better', 'to', 'me']
# ['i', 'find', 'that', 'if', 'the', 'coffe', 'bean', 'are', 'good', 'enough']
# ['you', 'realli', 'do', 'need', 'whi', 'are', 'you', 'in', 'a', 'wed', 'dress']
# ['well', 'i', 'sort', 'of', 'suppos', 'to']
# ['get', 'marri', 'today']
# ['all', 'your', 'friend', 'and', 'famili', 'are', 'wait', 'for', 'you']
# ['in', 'some', 'church', 'right', 'now']
# ['well', 'not', 'all', 'we', 'had', 'five']
# ['well', 'six']
# ['mazel', 'tov', 'ted']
# ['i', 'wa', 'start', 'to', 'think', 'thi', 'would', 'never', 'happen']
# ['oh', 'no', 'matsen']
# ['matsen', 'i', 'told', 'you', 'he', 'wa', 'gay']
# ['wait', 'what']
# ['i', 'wa', 'tempt', 'to', 'leav', 'klau', 'for', 'you', 'last', 'fall']
# ['the', 'onli', 'thing', 'hold', 'me', 'back', 'wa', 'the', 'robin', 'of', 'it', 'all']
# ['i', 'know', 'and', 'you', 'were', 'right', 'but', 'but', 'that', 'all', 'over', 'now']
# ['she', 'move', 'out', 'i', 'mean', 'still', 'friend', 'but', 'that', 'over']
# ['all', 'these', 'year', 'i', 'never', 'stop', 'think', 'about', 'you', 'ted']
# ['i', 'got', 'a', 'car', 'outsid']
# ['if', 'you', 'readi', 'to', 'drive', 'off', 'into', 'the', 'sunset', 'togeth']
# ['but', 'if', 'you', 'do', 'feel', 'the', 'same', 'way']
# ['if', 'you', 'close', 'the', 'door', 'on', 'us']
# ['just', 'say', 'the', 'word']
# ['and', 'i', 'go']
# ['barney', 'tell', 'them', 'the', 'trick']
# ['the', 'onli', 'person', 'i', 'could', 'possibl', 'reveal', 'the', 'trick', 'to']
# ['is', 'anoth', 'magician']
# ['well', 'i', 'a', 'magician']
# ['prove', 'it']
# []
# ['gasp']
# ['narrat', 'i', 'that', 'barney']
# ['i', 'quinn', 'said', 'it', 'wa', 'i', 'a', 'simpl', 'card']
# ['i', 'who', 'to', 'say', 'which', 'i', 'version', 'wa', 'true']
# ['i', 'i', 'quinn', 'version', 'wa']
# ['okay']
# ['i', 'tell', 'you']
# ['oh', 'that', 'realli', 'cool']
# ['so', 'what', 'the', 'trick']
# ['i', 'ca', 'say', 'magician', 'code']
# ['gasp']
# []
# ['cell', 'phone', 'ring']
# ['hello']
# ['whi', 'did', 'you', 'make', 'me', 'call', 'victoria']
# ['she', 'here', 'in', 'a', 'wed', 'dress']
# ['i', 'the', 'verg', 'of', 'ruin', 'a', 'wed']
# ['and', 'madsen', 'friend', 'think', 'i', 'gay']
# ['but', 'let', 'put', 'a', 'pin', 'in', 'that', 'till', 'later']
# ['oh', 'my', 'god', 'victoria', 'at', 'the', 'bar', 'with', 'ted']
# ['that', 'a', 'seven']
# ['and', 'she', 'in', 'a', 'wed', 'dress']
# ['that', 'a', 'ten']
# ['we', 'got', 'a', 'ten']
# ['what', 'are', 'you', 'gon', 'na', 'do', 'where', 'is', 'she', 'right', 'now']
# ['so', 'thi', 'dress', 'what', 'the', 'cut']
# ['are', 'we', 'talk', 'princess', 'ball', 'gown', 'column']
# ['right', 'it', 'a', 'feder', 'crime', 'to', 'love', 'wed']
# ['she', 'in', 'the', 'bathroom', 'which', 'i', 'guess']
# ['take', 'forev', 'with', 'that', 'giant', 'poufi', 'skirt', 'thing']
# ['ball', 'gown', 'thank', 'you']
# ['four', 'shot', 'of', 'tequila']
# ['ted', 'calm', 'down']
# ['or', 'not', 'thi', 'is', 'your', 'chanc', 'to', 'get', 'the', 'one', 'who', 'got', 'away']
# ['you', 'want', 'her', 'she', 'want', 'you']
# ['what', 'the', 'problem']
# ['the', 'problem', 'is', 'victoria', 'in', 'the', 'middl', 'of', 'a', 'giant']
# ['what', 'if', 'she', 'wind', 'up', 'regret', 'thi', 'decis']
# ['she', 'go', 'after', 'ted', 'mosbi']
# ['that', 'the', 'best', 'decis', 'she', 'ever', 'made']
# ['there', 'you', 'go']
# ['whoa', 'what', 'wa', 'that', 'what']
# ['you', 'said', 'you', 'want', 'a', 'pictur', 'of', 'babi', 'marvin', 'first', 'outing']
# ['our', 'babi', 'first', 'outing']
# ['wa', 'to', 'a', 'bar']
# ['gasp']
# ['i', 'dribbl', 'cuervo', 'on', 'marv', 'soft', 'spot']
# ['here', 'she', 'come', 'quick']
# ['oh', 'yeah']
# ['eggshel', 'or', 'cream']
# ['is', 'it', 'eggshel', 'or', 'cream']
# ['so']
# ['you', 'me', 'ride', 'off', 'into', 'the', 'sunset']
# ['ani', 'thought']
# ['one', 'question']
# ['fdr', 'or', 'westsid', 'highway']
# ['what', 'the', 'quickest', 'way', 'to', 'the', 'sunset']
# ['man', 'i', 'wind', 'up', 'in', 'these', 'room', 'a', 'lot']
# ['if', 'we', 'miss', 'hawaii', 'becaus', 'of', 'thi', 'guess', 'who', 'not', 'do']
# ['the', 'disappear', 'salami', 'anytim', 'soon']
# ['i', 'need', 'to', 'ask', 'you', 'both', 'a', 'few', 'question']
# ['let', 'start', 'with', 'you']
# ['name']
# ['quinn', 'garvey']
# ['occup']
# ['unemploy']
# ['well', 'well', 'well']
# ['look', 'who', 'keep', 'secret', 'now']
# ['sir', 'i', 'tell', 'you', 'her', 'occup', 'stripper']
# ['she', 'insist', 'she', 'proud', 'of', 'it']
# ['but', 'appar', 'not', 'proud', 'enough', 'to', 'tell', 'you']
# ['barney', 'i', 'wa', 'go', 'to', 'surpris', 'you', 'with', 'thi', 'on', 'our', 'trip']
# ['but', 'i', 'quit']
# ['you', 'did', 'that', 'for', 'me']
# ['ye']
# ['and', 'now', 'that', 'you', 'know', 'what', 'i', 'did', 'for', 'you']
# ['and', 'how', 'much', 'i', 'care', 'for', 'you']
# ['would', 'you', 'pleas', 'show', 'him', 'the', 'trick']
# ['sorri', 'magician', 'code']
# ['where', 'should', 'we', 'go']
# ['your', 'place']
# ['my', 'place']
# ['we', 'could', 'go', 'on', 'my', 'honeymoon']
# ['laugh']
# ['just', 'kid']
# ['although', 'it', 'is', 'paid', 'for']
# ['i', 'know', 'where', 'we', 'should', 'go', 'where']
# ['your', 'wed']
# ['i', 'take', 'you', 'back']
# ['i', 'do', 'understand']
# ['i', 'thought', 'you', 'want', 'thi']
# ['i', 'do', 'want', 'thi']
# ['i', 'thought', 'about', 'you', 'so', 'mani', 'time']
# ['what', 'might', 'have', 'been']
# ['but', 'i', 'got', 'left', 'at', 'the', 'altar', 'and', 'it', 'nearli', 'kill', 'me']
# ['you', 'someon']
# ['and', 'i', 'have', 'to', 'respect', 'that']
# ['so', 'let', 'hit', 'a', 'motel', 'jam', 'in', 'a', 'quicki']
# ['and', 'get', 'you', 'back', 'to', 'your', 'wed']
# ['giggl']
# ['it', 'the', 'right', 'thing', 'to', 'do']
# ['some', 'part', 'of', 'me', 'need', 'to', 'hear', 'you', 'say']
# ['that', 'run', 'away', 'togeth', 'wa', 'an', 'option']
# ['and', 'now', 'that', 'i', 'know', 'that']
# ['it', 'like', 'i', 'sober', 'up']
# ['is', 'there', 'ani', 'way']
# ['that', 'we', 'can', 'just', 'pretend', 'thi', 'never', 'happen']
# ['thi', 'never', 'happen']
# ['flanagan', 'bang', 'my', 'mom']
# ['well']
# ['your', 'flight', 'left']
# ['we', 'need', 'to', 'hold', 'stinson', 'for', 'further', 'question']
# ['but', 'you', 'free', 'to', 'go']
# ['mayb', 'i', 'should']
# ['wait']
# ['i', 'show', 'you', 'the', 'trick']
# ['sir']
# ['may', 'i', 'pleas', 'have', 'the', 'silk', 'handkerchief']
# ['in', 'your', 'top', 'left', 'breast', 'pocket']
# ['well', 'i', 'do', 'have']
# ['chuckl']
# ['clear', 'throat']
# ['sim', 'salabi', 'ma', 'sim', 'salabi', 'ma']
# ['gasp']
# ['relax', 'relax', 'it', 'part', 'of', 'the', 'trick']
# ['how', 'did', 'you', 'get', 'that', 'through', 'the', 'machin']
# ['no', 'question', 'from', 'the', 'audienc', 'pleas']
# ['chant', 'nonsens', 'syllabl']
# ['what', 'is', 'that']
# ['madam', 'may', 'i', 'pleas', 'have']
# ['the', 'key', 'on', 'your', 'necklac']
# ['oh']
# ['giggl']
# ['beep']
# ['is', 'that', 'gon', 'na', 'explod']
# ['what']
# ['scream']
# ['cough']
# ['ahem']
# ['mock', 'gasp']
# ['what']
# ['loudli', 'will', 'you', 'marri', 'me']
# ['ye']
# ['laugh']
# ['come', 'on', 'guy']
# ['we', 'lose', 'the', 'light', 'for', 'babi', 'second', 'first', 'outing']
# ['narrat', 'i', 'i', 'hate', 'to', 'say', 'it', 'i', 'but', 'robin', 'nail']
# ['door', 'close']
# ['hey', 'guy', 'we', 'got', 'someth', 'to', 'tell', 'you']
# ['eight', 'or', 'higher', 'bro']
# ['we', 'engag']
# ['that', 'a', 'that', 'a', 'ten']
# ['we', 'got', 'anoth', 'ten']
# ['oh', 'wow', 'big', 'day']
# ['congratul', 'thank', 'you']
# ['how', 'did', 'thi', 'happen']
# ['oh', 'magic']
# ['oh']
# ['uh', 'not', 'to', 'ruin', 'the', 'moment']
# ['but', 'appar', 'littl', 'marvin', 'is', 'quit', 'stun', 'by', 'the', 'news']
# ['well']
# ['yeah', 'wow', 'yeah']
# ['do', 'you', 'guy', 'mind', 'recount', 'thi', 'romant', 'tale']
# ['next', 'to', 'a', 'diaper', 'geni']
# ['oh', 'marvin', 'you', 'about', 'to', 'hear', 'your', 'first', 'love', 'stori']
# ['quinn', 'onc', 'up', 'on', 'a', 'time']
# ['thi', 'creepi', 'magic', 'dude', 'wa', 'bone', 'barney', 'mom']
# ['it', 'our', 'last', 'chanc', 'to', 'run', 'away', 'togeth']
# ['door', 'right', 'there']
# ['ye', 'we', 'start', 'a', 'new', 'life']
# ['head', 'for', 'the', 'border', 'canada']
# ['eh', 'mexico', 'canada', 'suck']
# ['okay', 'well', 'you', 'canadian']
# ['so', 'by', 'that', 'logic', 'you', 'suck']
# ['i', 'awesom']
# ['and', 'you', 'know', 'it']
# ['yeah', 'i', 'do']
# ['clear', 'throat']
# ['look', 'hope', 'thi', 'is', 'weird', 'or', 'anyth', 'becaus']
# ['barney']
# ['i', 'i', 'realli', 'happi', 'for', 'you']
# ['realli']
# ['i', 'listen', 'to', 'the', 'wind']
# ['realli']
# ['to', 'the', 'wind', 'of', 'my', 'soul']
# ['where', 'i', 'end', 'up', 'well', 'i', 'think']
# ['onli', 'god', 'realli', 'know']
# ['i', 'sat', 'upon']
# ['the', 'set', 'sun']
# ['but', 'never', 'never', 'never']
# ['you', 'just', 'drove', 'right', 'by', 'the', 'church']
# ['i', 'know']
# ['i', 'never', 'want', 'water', 'onc']
# ['no', 'never', 'never', 'never']
# ['i', 'listen', 'to', 'my', 'word']
# ['but', 'they', 'fall', 'far', 'below']
# ['the', 'road', 'to', 'thi', 'day', 'ha', 'had']
# ['a', 'few', 'twist', 'and', 'turn', 'ha', 'it']
# ['yeah', 'just', 'a', 'few']
# ['my', 'heart', 'want', 'to', 'go']
# ['in', 'a', 'weird', 'way', 'it', 'all', 'make', 'sens', 'though', 'doe', 'it']
# ['yeah']
# ['yeah', 'it', 'kind', 'of', 'doe']
# ['the', 'devil', 'lake']
# ['but', 'never', 'never']
# ['never', 'never']
# ['the', 'bride', 'want', 'to', 'see', 'me']
# ['no', 'never', 'never', 'never']
# ['sync', 'correct', 'by', 'font', 'elderman', 'font', 'visit', 'to', 'download']
# ['font']
# ['dad', 'we', 'need', 'to', 'talk', 'is', 'it', 'about', 'the', 'bee', 'visit', 'to', 'download']
# ['bee', 'we', 'throw']
# ['a', 'housewarm', 'parti', 'in', 'two', 'week']
# ['oh']
# ['it', 'gon', 'na', 'be', 'friend', 'neighbor']
# ['did', 'he', 'say', 'did', 'he', 'say', 'bee']
# ['yeah', 'marshal', 'been', 'work', 'veri', 'long', 'hour', 'late']
# ['so', 'i', 'have', 'been', 'plan', 'thi', 'whole', 'parti', 'by', 'myself']
# ['and', 'everyth', 'in', 'place', 'the', 'food', 'the', 'wine']
# ['i', 'even', 'found', 'a', 'rare', 'gouda', 'on', 'the', 'internet']
# ['oh']
# ['get', 'back', 'to', 'these', 'bee']
# ['bottom', 'line', 'thi', 'parti', 'is', 'veri', 'import', 'to', 'me']
# ['so', 'i', 'can', 'onli', 'assum', 'and', 'i', 'say', 'thi', 'with', 'love']
# ['you', 'gon', 'na', 'ruin', 'it']
# ['lili', 'i', 'promis', 'i', 'wo', 'ruin', 'your', 'parti']
# ['i', 'be', 'charm', 'and', 'convivi']
# ['a', 'regular', 'burt', 'reynold']
# ['you', 'have', 'absolut', 'noth', 'to', 'worri', 'about']
# ['tell', 'us', 'about', 'the', 'bee']
# ['well', 'all', 'right', 'sinc', 'you', 'ask']
# ['i', 'start', 'up', 'a', 'busi']
# ['cultiv', 'artisan', 'honey']
# ['that', 'right', 'i', 'a', 'job', 'creator']
# ['oh', 'so', 'thi', 'parti']
# ['oh', 'lili', 'wait', 'um', 'if', 'you', 'do', 'mind']
# ['i', 'just', 'i', 'have', 'one']
# ['where', 'are', 'you', 'do', 'thi', 'exactli']
# ['downstair', 'there', 'bee', 'in', 'the', 'basement']
# ['font', 'how', 'i', 'met', 'your', 'mother', 'font', 'the', 'burn', 'beekeep', 'origin', 'air', 'date', 'on', 'februari', 'visit', 'to', 'download']
# ['sync', 'correct', 'by', 'font', 'elderman', 'visit', 'to', 'download']
# ['ted', 'whi', 'would', 'you', 'even', 'say', 'that', 'it', 'the', 'most', 'ridic']
# ['both', 'happi', 'housewarm']
# ['hey', 'guy']
# ['robin', 'here', 'ha', 'spent']
# ['all', 'day', 'learn', 'how', 'to', 'make', 'kugel']
# ['could', 'figur', 'it', 'out', 'thi', 'is', 'from', 'zabar']
# ['can', 'we', 'heat', 'it', 'up', 'in', 'your', 'oven']
# ['faster', 'than', 'heat', 'it', 'up', 'in', 'the', 'refriger']
# ['chuckl']
# ['i', 'had', 'a', 'few', 'cocktail']
# ['i', 'got', 'it', 'take', 'that']
# ['narrat', 'i', 'kid', 'someday', 'i', 'you', 'gon', 'na', 'throw', 'a', 'parti']
# ['i', 'and', 'you', 'might', 'find', 'yourself', 'i', 'worri']
# ['i', 'if', 'someth', 'gon', 'na', 'go']
# ['i', 'well']
# ['i', 'what', 'you', 'should', 'worri', 'about', 'i', 'is', 'everyth', 'go']
# ['i', 'and', 'what', 'realli', 'scari', 'i', 'is', 'how', 'quickli', 'that', 'can']
# ['i', 'at', 'lili', 'and', 'marshal', 'i', 'housewarm', 'parti']
# ['i', 'for', 'instanc', 'i', 'it', 'onli', 'took', 'five']
# ['i', 'now', 'a', 'lot', 'happen', 'i', 'in', 'those', 'five']
# ['i', 'you', 'know', 'what', 'i', 'gon', 'na', 'take', 'i', 'thi', 'room', 'by']
# ['i', 'we', 'start', 'in', 'the', 'live']
# ['oh', 'no', 'that', 'not', 'what', 'you', 'want']
# ['what', 'oh', 'noth', 'so', 'you', 'think']
# ['thi', 'is', 'go', 'pretti', 'well']
# ['babi', 'are', 'you', 'kid']
# ['you', 'pull', 'off', 'the', 'parti', 'of', 'the', 'year']
# ['oh', 'stop', 'it', 'i', 'use', 'both', 'hand']
# ['so', 'what', 'can', 'i', 'do', 'to', 'help']
# ['honey', 'thi', 'is', 'your', 'first', 'night', 'off', 'in', 'howev', 'long']
# ['you', 'just', 'relax', 'and', 'keep', 'knock', 'back', 'those', 'cocktail']
# ['coot']
# ['hey', 'is', 'it', 'nice', 'to', 'final', 'have', 'a', 'night', 'off']
# ['it', 'is', 'but', 'tonight', 'is', 'not', 'i', 'that', 'night']
# ['we', 'go', 'back', 'to', 'the', 'offic', 'in', 'minut']
# ['but', 'sir', 'thi', 'is', 'our', 'housewarm', 'parti']
# ['you', 'know', 'mother', 'earth', 'is', 'also', 'have']
# ['a', 'housewarm', 'parti', 'too']
# ['onli', 'her', 'end', 'with', 'humankind', 'at', 'the', 'bottom', 'of', 'a', 'rise', 'ocean']
# ['pass', 'through', 'the', 'digest', 'tract', 'of', 'a', 'stingray']
# ['by', 'the', 'way', 'it', 'a', 'love', 'home']
# ['coot', 'i', 'know', 'you', 'a', 'vegan', 'so', 'i', 'uh']
# ['i', 'got', 'some', 'vegan', 'spring', 'roll', 'for', 'you', 'over', 'there']
# ['oh', 'nummi']
# ['you', 'go', 'back', 'to', 'work']
# ['sheez', 'marshal', 'you', 'are', 'as', 'busi', 'as', 'a']
# ['oh', 'gosh', 'what', 'are', 'you', 'as', 'busi', 'as']
# ['pleas', 'do', 'talk', 'about', 'the', 'bee']
# ['i', 'wa', 'gon', 'na', 'say', 'nicola', 'cage']
# ['that', 'guy', 'is', 'in', 'everyth']
# ['let', 'just', 'put', 'on', 'some', 'music']
# []
# ['i', 'uh', 'i', 'bring', 'out', 'the', 'gouda']
# ['we', 'open', 'a', 'coupl', 'bottl', 'of', 'wine']
# ['that', 'are', 'in', 'the', 'basement']
# ['all', 'right', 'i', 'get', 'my', 'beekeep', 'suit']
# ['you', 'should', 'be', 'happi', 'about', 'the', 'bee']
# ['they', 'keep', 'the', 'mice', 'at', 'bay']
# ['we', 'have', 'mice']
# ['not', 'with', 'all', 'these', 'bee']
# ['fli', 'around', 'we', 'do']
# ['you', 'welcom']
# ['ted', 'babi', 'come', 'out', 'look', 'aliv']
# ['are', 'you', 'a', 'vegan']
# ['what']
# []
# ['kitchen', 'now']
# ['i', 'ca', 'believ', 'that', 'make', 'us', 'go', 'to', 'work', 'tonight']
# ['are', 'you', 'a', 'vegan']
# ['um', 'no']
# ['and', 'when', 'you', 'were', 'shovel']
# ['the', 'spring', 'roll', 'down', 'your', 'gullet', 'did', 'you', 'happen', 'to', 'notic']
# ['a', 'littl', 'sign', 'next', 'to', 'the', 'plate', 'mark', 'vegan']
# ['i', 'think', 'been', 'some', 'mistak']
# ['you', 'could', 'have', 'had', 'anyth', 'on', 'that', 'tabl']
# ['anyth', 'at', 'all']
# ['mini', 'pizza', 'fig']
# ['pig', 'in', 'blanket']
# ['there', 'wa', 'even', 'talk', 'of', 'an', 'inbound', 'gouda']
# ['but', 'no', 'no', 'you', 'had', 'to', 'have', 'the', 'one', 'thing']
# ['that', 'someon', 'with', 'my', 'dietari', 'prefer', 'can', 'eat']
# ['look', 'i', 'did', 'eat', 'the', 'spring', 'roll']
# ['liar']
# ['your', 'breath', 'reek', 'of', 'shred', 'carrot', 'and', 'deceit']
# ['okay', 'okay', 'mayb', 'i', 'did', 'eat', 'your', 'preciou', 'spring', 'roll']
# ['oh']
# ['what', 'are', 'you', 'gon', 'na', 'do', 'about', 'it', 'i', 'hippi']
# ['woman', 'scream']
# ['it', 'fine', 'everyth', 'fine']
# ['young', 'man']
# ['are', 'you', 'suggest', 'fisticuff']
# ['as', 'in', 'with', 'our', 'fist']
# ['and', 'feet', 'i', 'a', 'kicker']
# ['well', 'well', 'look', 'like', 'i', 'just', 'start', 'eat']
# ['white', 'meat', 'again']
# ['i', 'will', 'bite', 'and', 'scratch', 'you', 'like', 'a', 'wolverin']
# ['may', 'i', 'warn', 'you']
# ['i', 'have', 'been', 'in', 'a', 'fight', 'befor']
# ['so', 'have', 'i', 'sort', 'of']
# ['oh', 'god']
# ['coot', 'hi']
# ['did', 'you', 'see', 'that', 'we', 'had', 'hummu', 'and', 'veggi']
# ['there', 'hummu', 'and', 'veggi']
# ['over', 'there']
# ...
# ['so', 'do', 'be', 'that', 'guy']
# ['you', 'right', 'you', 'right']
# ['i', 'got', 'it', 'forget', 'i', 'said', 'anyth']
# ['hmm']
# ['i', 'see', 'you', 'tonight', 'karma']
# ['you', 'got', 'it', 'dirti', 'larri']
# ['you', 'have', 'to', 'quit', 'your', 'job']
# ['narrat', 'i', 'that', 'night', 'i', 'went', 'out']
# ['i', 'with', 'the', 'first', 'girl', 'i', 'barney', 'pick', 'for']
# ['i', 'there', 'wa', 'just', 'one']
# ['your', 'name', 'is', 'robin']
# ['yeah', 'with', 'a', 'y']
# ['oh', 'i']
# ['no', 'robin']
# ['i', 'go', 'by', 'scotchandgunlov', 'in', 'my', 'onlin', 'profil']
# ['those', 'are', 'my', 'two', 'favorit', 'thing']
# ['well', 'next', 'to', 'canada', 'my', 'home', 'and', 'nativ', 'land']
# ['oh', 'canada']
# ['narrat', 'i', 'and', 'just', 'like', 'that']
# ['i', 'robyn', 'becam']
# ['how', 'it', 'go', 'ted']
# ['oh', 'good', 'hey', 'look', 'mommi', 'back', 'from', 'the', 'bar']
# ['now', 'i', 'can', 'final', 'take', 'a', 'shower']
# ['sigh']
# ['thi', 'diaper', 'smell', 'i', 'do', 'want', 'to', 'know']
# ['okay', 'marshal']
# ['sit', 'down', 'we', 'need', 'to', 'talk']
# ['sigh']
# ['look', 'i', 'know', 'you', 'mean', 'well']
# ['but', 'we', 'have', 'five', 'week', 'till', 'the', 'due', 'date']
# ['ca', 'we', 'use', 'thi', 'time', 'to', 'just', 'relax']
# ['we', 'figur', 'out', 'how', 'all', 'thi', 'stuff']
# ['work', 'after', 'the', 'babi', 'come']
# ['after', 'the', 'babi', 'come']
# ['yeah', 'we', 'learn', 'on', 'the', 'job']
# ['learn', 'on', 'the', 'j', 'huh']
# ['wow', 'you', 'know', 'lili']
# ['mayb', 'the', 'crisi', 'here', 'is', 'that', 'i', 'not', 'readi', 'to', 'be', 'a', 'dad']
# ['mayb', 'it', 'that', 'you', 'not', 'readi', 'to', 'be', 'a', 'mom']
# ['excus', 'me', 'yeah']
# ['narrat', 'i', 'with', 'that', 'i', 'an', 'argument', 'began']
# ['the', 'detail', 'of', 'which', 'are', 'still', 'i', 'hotli', 'debat', 'to', 'thi']
# ['i', 'for', 'instanc', 'uncl', 'marshal', 'i', 'swear', 'he', 'never', 'said']
# ['i', 'the', 'onli', 'one', 'make', 'sacrific', 'for', 'thi', 'babi']
# ['what']
# ['i', 'and', 'he', 'claim', 'he', 'never', 'i', 'actual', 'utter', 'the', 'word']
# ['it', 'like', 'you', 'do', 'even', 'know', 'that', 'you', 'pregnant']
# ['i', 'while', 'lili', 'insist', 'i', 'thi', 'part', 'wa', 'exagger']
# ['babi', 'are', 'easi', 'you', 'just']
# ['watch', 'them', 'be', 'cute', 'and', 'feed', 'them', 'spaghetti']
# ['i', 'but', 'everyon', 'agre', 'i', 'thi', 'is', 'how', 'the', 'argument', 'end']
# ['marshal', 'what', 'i', 'need', 'now', 'is', 'some', 'peac', 'some', 'quiet']
# ['and', 'now', 'that', 'it', 'out', 'there', 'some', 'spaghetti']
# ['now', 'pleas', 'help', 'me', 'off', 'the', 'couch', 'so', 'i', 'can', 'storm', 'out']
# ['angri', 'grunt', 'huh']
# ['narrat', 'i', 'the', 'next', 'day', 'i', 'i', 'fill', 'barney', 'in', 'on', 'my']
# ['oh', 'yobin']
# ['no', 'robin']
# ['and', 'for', 'the', 'rest', 'of', 'the', 'night']
# ['everi', 'time', 'i', 'look', 'at', 'her', 'i', 'just', 'saw', 'robin', 'face']
# ['well', 'i', 'should', 'hope', 'so', 'no', 'our', 'robin']
# ['robin', 'with', 'an', 'i']
# ['uh', 'our', 'robin', 'ha', 'two', 'eye', 'my', 'friend']
# ['but', 'that', 'good', 'forget', 'what', 'she', 'look', 'like']
# ['i', 'sorri', 'that', 'must', 'have', 'been', 'tough']
# ['if', 'anyon', 'know', 'what', 'that', 'feel', 'like', 'it', 'me']
# ['my', 'condol']
# ['okay', 'move', 'on']
# ['the', 'next', 'girl', 'perfect', 'palat', 'cleanser']
# ['noth', 'like', 'robin']
# ['how', 'noth']
# ['i', 'gaze', 'out', 'into', 'the', 'world', 'and', 'all', 'i', 'see']
# ['is', 'an', 'ici', 'place', 'where', 'dream', 'die']
# ['ooh', 'lasagna']
# ['how', 'it', 'go', 'ted']
# ['what', 'no', 'what']
# ['rememb', 'i', 'made', 'lasagna', 'that', 'one', 'time']
# ['that', 'all', 'it', 'take']
# ['it', 'wa', 'even', 'lasagna', 'you', 'took', 'your', 'botch', 'kugl']
# ['and', 'pour', 'tomato', 'sauc', 'on', 'it']
# ['i', 'did', 'say', 'it', 'wa', 'good', 'lasagna']
# ['by', 'the', 'way', 'what', 'are', 'you', 'do', 'with', 'thi', 'girl']
# ['with', 'tattoo', 'all', 'up', 'and', 'down', 'her', 'arm', 'and']
# ['everywher', 'els', 'hello', 'good', 'gravi']
# ['doe', 'that', 'dragon', 'tail', 'go', 'all', 'the', 'way', 'down', 'to', 'her']
# ['chuckl', 'ohh', 'ye', 'it', 'doe']
# ['well', 'what', 'do', 'you', 'want', 'me', 'to', 'do', 'robin']
# ['i', 'have', 'to', 'get', 'over', 'you', 'somehow']
# ['and', 'if', 'thi', 'is', 'what', 'it', 'take']
# ['are', 'you', 'okay']
# ['yeah', 'whi']
# ['you', 'kind', 'of', 'space', 'out', 'there']
# ['weirdo']
# ['so', 'in', 'summat']
# ['i', 'veri', 'veri', 'sorri']
# ['i', 'guess', 'i', 'just', 'want', 'you', 'all', 'to', 'myself']
# ['and', 'then', 'i', 'thought', 'of', 'all', 'the', 'creepi', 'guy', 'grope', 'at', 'your']
# ['okay', 'i', 'get', 'mad', 'again']
# ['so', 'i', 'go', 'to', 'stop', 'write', 'now']
# ['pleas', 'enjoy', 'these', 'chocol', 'may', 'contain', 'peanut']
# ['kiss', 'and', 'make', 'up']
# ['chuckl']
# ['have', 'sex', 'up', 'against', 'the', 'window', 'and', 'make', 'up', 'laugh']
# ['you', 'do', 'have', 'a', 'great', 'view']
# ['well', 'funni', 'you', 'should', 'mention', 'that']
# ['it', 'i', 'your', 'view']
# ['come', 'again', 'for', 'big', 'fudg']
# ['congratul', 'you', 'hire']
# ['you', 'are', 'goliath', 'nation', 'bank']
# ['newest', 'execut', 'strategi', 'coordin']
# ['what', 'is', 'an', 'execut', 'strategi', 'coordin']
# ['it', 'three', 'word']
# ['which', 'when', 'ad', 'togeth', 'equal', 'a', 'fake', 'job']
# ['for', 'which', 'you', 'get', 'a', 'real', 'paycheck']
# ['in', 'the', 'amount', 'of', 'exactli', 'what', 'you', 'make', 'strip']
# ['plu', 'dental', 'you', 'welc']
# ['now', 'about', 'that', 'sex']
# ['dude', 'i', 'do', 'want', 'to', 'work', 'for', 'a', 'bank']
# ['whi', 'not']
# ['becaus', 'i', 'have', 'standard']
# ['you', 'peopl', 'are', 'whore']
# ['the', 'thing', 'you', 'will', 'to', 'do', 'just', 'for', 'some', 'money']
# ['it', 'shame']
# ['you', 'work', 'in', 'a', 'strip', 'club']
# ['yeah', 'and', 'i', 'like', 'it']
# ['and', 'i', 'good', 'at', 'it']
# ['barney']
# ['if', 'i', 'took', 'thi', 'job', 'you', 'would', 'own', 'me']
# ['i', 'would', 'be', 'willingli', 'step', 'into', 'a', 'cage']
# ['which', 'is', 'someth', 'i', 'do', 'do']
# ['except', 'on', 'thursday', 'when', 'cage', 'night', 'at', 'the', 'lusti', 'leopard']
# ['but', 'that', 'a', 'cardboard', 'cage']
# ['and', 'i', 'can', 'get', 'out', 'of', 'it', 'ani', 'time', 'i', 'want']
# ['you', 'can']
# ['wow', 'thank', 'for', 'ruin', 'cage', 'night']
# ['come', 'on', 'quinn', 'no']
# ['i', 'would', 'nope']
# ['do']
# ['i', 'think', 'i', 'have', 'some', 'think', 'to', 'do']
# ['i']
# ['stinson']
# ['doe', 'thi', 'mean', 'i', 'get', 'to', 'keep', 'my', 'job']
# ['sigh', 'yeah', 'herm', 'you', 'can', 'stay']
# ['hey', 'babi', 'listen']
# ['sorri', 'i', 'flip', 'out']
# ['oh', 'that', 'okay']
# ['to', 'be', 'fair', 'mayb', 'i', 'at', 'fault']
# ['for', 'love', 'our', 'child', 'too', 'much']
# ['although', 'that', 'is', 'the', 'definit', 'of', 'parent', 'so']
# ['all', 'right', 'good', 'make', 'up']
# ['hey', 'listen', 'i', 'went', 'onlin']
# ['and', 'i', 'found', 'thi', 'babi', 'boot', 'camp', 'thing']
# ['that', 'they', 'do', 'at', 'a', 'hotel', 'in', 'paramu', 'thi', 'weekend']
# ['babi', 'boot', 'camp']
# ['that', 'sound', 'great']
# ['yeah', 'it', 'a', 'event']
# ['we', 'go']
# ['and', 'there', 'lot', 'of', 'seminar', 'and', 'class']
# ['you', 'alreadi', 'made', 'the', 'sale']
# ['anyway', 'i', 'sign', 'us', 'up']
# ['not', 'even', 'listen', 'anymor', 'mental', 'pack']
# ['i', 'tri', 'to', 'figur', 'out', 'the', 'best', 'way', 'to', 'get', 'to', 'paramu']
# ['without', 'hit', 'ani', 'toll']
# ['thi', 'is', 'gon', 'na', 'be', 'great']
# ['and', 'that', 'wa', 'the', 'last', 'time']
# ['i', 'ever', 'go', 'out', 'with', 'a', 'guy', 'with', 'a', 'mustach']
# ['both', 'chuckl']
# ['i', 'thi', 'is']
# ['i', 'thi', 'is', 'nice', 'not', 'think', 'i', 'about']
# ['i', 'just', 'have', 'a', 'good', 'time']
# ['and', 'thank', 'god', 'i', 'did', 'grow', 'i', 'that']
# ['and', 'you']
# ['you', 'so', 'polit']
# ['my', 'wayn', 'he', 'had', 'no', 'manner']
# ['i', 'wayn', 'had', 'no']
# ['i', 'wayn', 'manner']
# ['i', 'wayn', 'manor', 'i', 'home', 'of', 'bruce', 'wayn']
# ['i', 'better', 'known', 'as', 'batman']
# ['i', 'mentor', 'to', 'dick', 'grayson', 'i', 'hi', 'orphan', 'ward']
# ['i', 'who', 'at', 'night', 'would', 'don', 'i', 'the', 'color', 'vestment']
# ['i', 'of', 'the', 'boy', 'wonder', 'aka']
# ['growl', 'robin']
# ['holi', 'long', 'walk', 'for', 'a', 'short', 'drink', 'of', 'water', 'ted']
# ['stop', 'thi']
# ['i', 'need', 'you', 'out', 'of', 'my', 'life', 'for', 'real']
# ['you', 'do', 'mean', 'that', 'ye', 'i', 'do']
# ['no', 'you', 'do']
# ['look', 'how', 'much', 'is', 'chang', 'right', 'now']
# ['marshal', 'and', 'lili', 'are', 'have', 'a', 'babi']
# ['barney', 'shack', 'up', 'with', 'a', 'girl']
# ['with', 'your', 'whole', 'world']
# ['turn', 'upsid', 'down']
# ['is', 'a', 'friendship', 'like', 'thi', 'one']
# ['someth', 'you', 'want', 'to', 'hold', 'on', 'to', 'as', 'tightli', 'as', 'possibl']
# ['and', 'everi', 'time', 'i', 'look', 'at', 'you', 'it', 'hurt']
# ['and', 'that', 'the', 'stori', 'of', 'my', 'onli', 'lesbian', 'experi']
# ['i', 'sorri']
# ['for', 'go', 'into', 'so', 'much', 'detail']
# ['i', 'never', 'tell', 'that', 'stori', 'again']
# ['anyway', 'how', 'your', 'meal']
# ['holli', 'listen', 'i', 'should', 'probabl', 'tell', 'you']
# ['um', 'i', 'kind', 'of', 'get', 'over', 'someon', 'right', 'now']
# ['i', 'am', 'so', 'glad', 'you', 'said', 'that']
# ['i', 'guess', 'i', 'still', 'get', 'over', 'wayn']
# ['it', 'been', 'realli', 'hard']
# ['can', 'i', 'interest', 'you', 'in', 'some', 'sorbet']
# ['you', 'two', 'look', 'like', 'you', 'could', 'both', 'use', 'a', 'palat', 'cleanser']
# ['exhal']
# ['how', 'your', 'palat', 'ted']
# ['pretti', 'cleans']
# ['chuckl']
# ['groan', 'you', 'know', 'at', 'thi', 'seminar']
# ['there', 'gon', 'na', 'be', 'the', 'one', 'guy', 'who', 'like']
# ['mr', 'parent', 'expert', 'keep', 'interrupt', 'the', 'speaker']
# ['with', 'hi', 'own', 'import', 'fact']
# ['and', 'you', 'gon', 'na', 'be', 'sit', 'right', 'next', 'to', 'him']
# ['so', 'get', 'readi', 'for', 'that']
# ['babi', 'you', 'been', 'a', 'littl', 'sleep', 'depriv', 'late']
# ['whi', 'do', 'you', 'let', 'me', 'drive']
# ['you', 'know', 'what', 'not', 'such', 'a', 'bad', 'idea']
# ['i', 'mean', 'the', 'last', 'thing', 'we', 'want']
# ['is', 'for', 'me', 'to', 'get', 'behind', 'the', 'wheel', 'and', 'just']
# ['snore']
# ['groan']
# ['moan']
# ['oh', 'babi', 'you', 'smell', 'good']
# ['when', 'we', 'get', 'to', 'that', 'hotel']
# ['i', 'gon', 'na', 'wear', 'your', 'pregnant', 'belli', 'like', 'a', 'hat']
# ['barney', 'you', 'have', 'to', 'buy', 'me']
# ['a', 'coupl', 'of', 'cocktail', 'first']
# []
# ['where', 'are', 'we']
# ['atlant', 'citi', 'babi']
# ['well', 'in', 'mile']
# ['what', 'the', 'hell', 'is', 'go', 'on']
# ['and', 'where', 'is', 'lili']
# ['and', 'what', 'did', 'you', 'do', 'to', 'the', 'practic', 'babi']
# ['and', 'is', 'there', 'ani', 'left']
# ['lili', 'wa', 'worri', 'about', 'you']
# ['she', 'thought', 'you', 'need', 'to', 'unwind', 'so']
# ['i', 'mean', 'the', 'last', 'thing', 'we', 'want', 'is', 'for', 'me', 'to']
# ['get', 'behind', 'the', 'wheel', 'and', 'just']
# ['snore']
# ['barney', 'i', 'she', 'made', 'reserv', 'i', 'for', 'two', 'delux', 'room']
# ['i', 'massag', 'and', 'dinner', 'i', 'at', 'the', 'palm']
# ['i', 'and', 'in', 'return', 'i', 'i', 'made', 'her']
# ['so', 'there', 'no', 'babi', 'boot', 'camp', 'at', 'the', 'paramu', 'waldorf']
# ['is', 'there', 'even', 'a', 'paramu', 'waldorf']
# ['bro']
# ['i', 'am', 'so', 'mad', 'at', 'lili', 'right', 'now']
# ['she', 'knew', 'you', 'would', 'be', 'that', 'whi', 'she', 'pack', 'thi']
# ['aw']
# ['my', 'shirt']
# ['i', 'had', 'thi', 'made', 'for', 'me']
# ['and', 'my', 'high', 'school', 'girlfriend', 'steph']
# ['in', 'realiti', 'marshal', 'and', 'steph']
# ['turn', 'out', 'to', 'be']
# ['marshal', 'and', 'steph', 'for', 'two', 'day']
# ['until', 'steph', 'boyfriend', 'got', 'out', 'of', 'juvi', 'a', 'week', 'earli']
# ['drive', 'lili', 'crazi', 'when', 'i', 'wear', 'it']
# ['i', 'hope', 'she', 'miser', 'without', 'me']
# ['crunch']
# ['hey', 'ted', 'how', 'trick']
# ['trick', 'are', 'pretti', 'good', 'lou']
# ['had', 'some', 'girl', 'troubl', 'earlier', 'in', 'the', 'week', 'but', 'uh']
# ['i', 'got', 'a', 'feel', 'from', 'here', 'on', 'out', 'thing', 'are', 'gon', 'na', 'be', 'a']
# ['you', 'son', 'of', 'a', 'bitch']
# ['hello']
# ['cheer']
# ['lili', 'right']
# ['i', 'been', 'act', 'crazi']
# ['no', 'it', 'okay', 'bro']
# ['i', 'mean', 'yeah', 'you', 'been', 'a', 'littl', 'crazi']
# ['but', 'it', 'come', 'from', 'love']
# ['it', 'the', 'same', 'kind', 'of', 'crazi', 'that', 'make', 'a', 'man']
# ['offer', 'hi', 'stripper', 'girlfriend', 'over', 'half', 'a', 'million', 'dollar']
# ['of', 'govern', 'bailout', 'money']
# ['not', 'to', 'rub', 'up', 'on', 'other', 'guy', 'junk']
# ['it', 'good', 'crazi']
# ['gambler', 'groan']
# ['i', 'hope', 'lili', 'okay', 'okay']
# ['you', 'know', 'that', 'it', 'bro']
# ['we', 'both', 'turn', 'off', 'our', 'phone', 'for', 'one', 'hour']
# ['motion', 'deni']
# ['okay', 'you', 'leav', 'me', 'no', 'choic']
# ['propos', 'you', 'give', 'me', 'one', 'hour', 'of', 'bro', 'time']
# ['dure', 'which', 'we', 'and', 'by', 'we', 'i', 'mean', 'you']
# ['get', 'magnific', 'mytholog', 'drunk']
# ['i', 'talk', 'drunk']
# ['if', 'you', 'can', 'give', 'me', 'that']
# ['i', 'will', 'wear', 'thi']
# ['the', 'ducki', 'tie']
# ['i', 'thought', 'you', 'threw', 'that', 'thing', 'away']
# ['i', 'did']
# ['it', 'came', 'back']
# ['all', 'right', 'barney']
# ['you', 'got', 'yourself', 'a', 'deal']
# ['chuckl']
# ['beep']
# ['um', 'excus', 'me', 'miss']
# ['um', 'when', 'you', 'get', 'a', 'chanc']
# ['could', 'you', 'bring', 'over', 'a', 'hundr', 'shot', 'of', 'tequila', 'pleas']
# ['i', 'have', 'the', 'same']
# ['whi', 'are', 'you', 'still', 'here']
# ['whi', 'do', 'you', 'think', 'i', 'still', 'here']
# ['i', 'guess', 'becaus', 'in', 'love', 'with', 'you']
# ['whi', 'els', 'would', 'i', 'be', 'see', 'your', 'face', 'everywher', 'i', 'look']
# ['becaus', 'you', 'feel', 'bad']
# ['of', 'cours', 'i', 'feel', 'bad']
# ['i', 'told', 'you', 'i', 'love', 'you']
# ['which', 'is', 'appar', 'the', 'worst', 'thing', 'you', 'can', 'say', 'to', 'someon']
# ['that', 'not', 'whi', 'you', 'feel', 'bad']
# ['you', 'feel', 'bad', 'becaus', 'after', 'you', 'said', 'it']
# ['you', 'let', 'me', 'go', 'away']
# ['i', 'know', 'our', 'relationship']
# ['is', 'exactli', 'what', 'you', 'want', 'it', 'to', 'be']
# ['and', 'i', 'know', 'i', 'may', 'not', 'love', 'you']
# ['the', 'way', 'you', 'love', 'me', 'but', 'i', 'do', 'love', 'you']
# ['is', 'that', 'worth', 'hang', 'on', 'to']
# ['sigh']
# ['i', 'miss', 'you']
# ['so', 'go', 'get', 'me', 'back']
# ['exhal']
# ['robin']
# ['ted']
# ['it', 'good', 'to', 'realli', 'see', 'you']
# ['it', 'realli', 'good', 'to', 'see', 'you']
# ['look', 'i', 'think', 'we', 'need', 'to', 'talk']
# ['uh', 'me', 'too', 'but', 'now', 'not', 'a', 'good', 'time']
# ['whi', 'not']
# ['i', 'am', 'proud', 'of', 'you', 'bro']
# ['you', 'turn', 'off', 'your', 'phone', 'for', 'one', 'hour']
# ['and', 'you', 'got', 'so', 'drunk']
# ['mumbl']
# ['exactli']
# ['hey', 'mumbl']
# ['ye', 'marshal']
# ['speak', 'untellig']
# ['well', 'i', 'do', 'see', 'whi', 'not']
# ['whoa', 'i', 'got', 'new', 'voicemail']
# ['barney', 'it', 'lili']
# ['you', 'guy', 'need', 'to', 'get', 'back', 'to', 'new', 'york', 'right', 'away']
# ['i', 'in', 'labor']
# ['marshal', 'yell']
# ['all', 'hail', 'beercul']
# ['laugh', 'yeah']
# ['laugh']
# ['groan']
# ['all', 'right', 'barney', 'you', 'got', 'yourself', 'a', 'deal']
# ['beep']
# ['hey', 'you', 'reach', 'marshal']
# ['pleas', 'leav', 'a', 'messag', 'beep']
# ['hey', 'babi', 'it', 'me']
# ['i', 'think', 'i', 'labor']
# ['cough', 'we', 'should', 'do', 'thi', 'everi', 'weekend']
# ['beep', 'okay', 'thi', 'is', 'real']
# ['it', 'not', 'a', 'fals', 'alarm']
# ['thi', 'is', 'real', 'i', 'in', 'labor']
# ['i', 'kind', 'of', 'need', 'you', 'to', 'call', 'me', 'back', 'now']
# ['how', 'doe', 'somebodi', 'so', 'littl']
# ['have', 'such', 'strong', 'finger']
# ['call', 'me']
# ['he', 'is', 'the', 'manag', 'of', 'the', 'paramu', 'waldorf']
# ['you', 'come', 'to', 'paramu', 'we', 'will', 'hook', 'you', 'up']
# ['beep', 'if', 'you', 'tri', 'to', 'get', 'back', 'at', 'me']
# ['you', 'have', 'chosen', 'a', 'wildli', 'inappropri', 'way', 'of', 'do', 'so']
# ['oh', 'yeah', 'oh', 'yeah']
# ['sync', 'correct', 'by', 'font', 'elderman']
# ['font']

# %% [markdown]
# ## Train the model

# %%
model = gensim.models.Word2Vec(final,batch_words=8,
                               size=100,iter=20,
                               window=10,
                               min_count=1,
                               workers=multiprocessing.cpu_count())
# Out:
# 2018-09-17 18:04:53,698 : INFO : collecting all words and their counts
# 2018-09-17 18:04:53,701 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-17 18:04:53,732 : INFO : PROGRESS: at sentence #10000, processed 56684 words, keeping 3907 word types
# 2018-09-17 18:04:53,738 : INFO : collected 4339 word types from a corpus of 68986 raw words and 12208 sentences
# 2018-09-17 18:04:53,745 : INFO : Loading a fresh vocabulary
# 2018-09-17 18:04:53,759 : INFO : effective_min_count=1 retains 4339 unique words (100% of original 4339, drops 0)
# 2018-09-17 18:04:53,761 : INFO : effective_min_count=1 leaves 68986 word corpus (100% of original 68986, drops 0)
# 2018-09-17 18:04:53,778 : INFO : deleting the raw counts dictionary of 4339 items
# 2018-09-17 18:04:53,780 : INFO : sample=0.001 downsamples 69 most-common words
# 2018-09-17 18:04:53,783 : INFO : downsampling leaves estimated 48713 word corpus (70.6% of prior 68986)
# 2018-09-17 18:04:53,806 : INFO : estimated required memory for 4339 words and 100 dimensions: 5640700 bytes
# 2018-09-17 18:04:53,808 : INFO : resetting layer weights
# 2018-09-17 18:04:53,865 : INFO : training model with 2 workers on 4339 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-17 18:04:54,871 : INFO : EPOCH 1 - PROGRESS: at 77.35% examples, 37866 words/s, in_qsize 4, out_qsize 4
# 2018-09-17 18:04:55,165 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:04:55,166 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:04:55,172 : INFO : EPOCH - 1 : training on 68986 raw words (48711 effective words) took 1.3s, 37443 effective words/s
# 2018-09-17 18:04:56,178 : INFO : EPOCH 2 - PROGRESS: at 77.93% examples, 38191 words/s, in_qsize 4, out_qsize 5
# 2018-09-17 18:04:56,461 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:04:56,463 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:04:56,468 : INFO : EPOCH - 2 : training on 68986 raw words (48800 effective words) took 1.3s, 37808 effective words/s
# 2018-09-17 18:04:57,478 : INFO : EPOCH 3 - PROGRESS: at 76.38% examples, 37359 words/s, in_qsize 0, out_qsize 1
# 2018-09-17 18:04:57,792 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:04:57,794 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:04:57,800 : INFO : EPOCH - 3 : training on 68986 raw words (48731 effective words) took 1.3s, 36846 effective words/s
# 2018-09-17 18:04:58,803 : INFO : EPOCH 4 - PROGRESS: at 79.74% examples, 39017 words/s, in_qsize 1, out_qsize 4
# 2018-09-17 18:04:59,060 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:04:59,061 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:04:59,065 : INFO : EPOCH - 4 : training on 68986 raw words (48698 effective words) took 1.3s, 38587 effective words/s
# 2018-09-17 18:05:00,074 : INFO : EPOCH 5 - PROGRESS: at 77.18% examples, 37722 words/s, in_qsize 4, out_qsize 4
# 2018-09-17 18:05:00,364 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:00,366 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:00,370 : INFO : EPOCH - 5 : training on 68986 raw words (48749 effective words) took 1.3s, 37600 effective words/s
# 2018-09-17 18:05:01,379 : INFO : EPOCH 6 - PROGRESS: at 79.46% examples, 38864 words/s, in_qsize 0, out_qsize 4
# 2018-09-17 18:05:01,655 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:01,657 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:01,661 : INFO : EPOCH - 6 : training on 68986 raw words (48737 effective words) took 1.3s, 38010 effective words/s
# 2018-09-17 18:05:02,670 : INFO : EPOCH 7 - PROGRESS: at 77.98% examples, 38090 words/s, in_qsize 2, out_qsize 3
# 2018-09-17 18:05:02,954 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:02,955 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:02,962 : INFO : EPOCH - 7 : training on 68986 raw words (48745 effective words) took 1.3s, 37690 effective words/s
# 2018-09-17 18:05:03,968 : INFO : EPOCH 8 - PROGRESS: at 77.00% examples, 37578 words/s, in_qsize 3, out_qsize 0
# 2018-09-17 18:05:04,258 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:04,259 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:04,267 : INFO : EPOCH - 8 : training on 68986 raw words (48666 effective words) took 1.3s, 37452 effective words/s
# 2018-09-17 18:05:05,273 : INFO : EPOCH 9 - PROGRESS: at 79.64% examples, 38898 words/s, in_qsize 4, out_qsize 4
# 2018-09-17 18:05:05,534 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:05,535 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:05,542 : INFO : EPOCH - 9 : training on 68986 raw words (48667 effective words) took 1.3s, 38328 effective words/s
# 2018-09-17 18:05:06,547 : INFO : EPOCH 10 - PROGRESS: at 79.94% examples, 39151 words/s, in_qsize 1, out_qsize 4
# 2018-09-17 18:05:06,800 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:06,802 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:06,807 : INFO : EPOCH - 10 : training on 68986 raw words (48828 effective words) took 1.3s, 38755 effective words/s
# 2018-09-17 18:05:07,814 : INFO : EPOCH 11 - PROGRESS: at 78.35% examples, 38337 words/s, in_qsize 4, out_qsize 5
# 2018-09-17 18:05:08,087 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:08,088 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:08,093 : INFO : EPOCH - 11 : training on 68986 raw words (48783 effective words) took 1.3s, 38157 effective words/s
# 2018-09-17 18:05:09,101 : INFO : EPOCH 12 - PROGRESS: at 79.60% examples, 38938 words/s, in_qsize 4, out_qsize 2
# 2018-09-17 18:05:09,361 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:09,362 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:09,371 : INFO : EPOCH - 12 : training on 68986 raw words (48732 effective words) took 1.3s, 38362 effective words/s
# 2018-09-17 18:05:10,377 : INFO : EPOCH 13 - PROGRESS: at 79.56% examples, 38843 words/s, in_qsize 4, out_qsize 5
# 2018-09-17 18:05:10,630 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:10,631 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:10,638 : INFO : EPOCH - 13 : training on 68986 raw words (48630 effective words) took 1.3s, 38534 effective words/s
# 2018-09-17 18:05:11,643 : INFO : EPOCH 14 - PROGRESS: at 79.67% examples, 38811 words/s, in_qsize 4, out_qsize 0
# 2018-09-17 18:05:11,902 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:11,904 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:11,910 : INFO : EPOCH - 14 : training on 68986 raw words (48520 effective words) took 1.3s, 38314 effective words/s
# 2018-09-17 18:05:12,918 : INFO : EPOCH 15 - PROGRESS: at 80.74% examples, 39593 words/s, in_qsize 1, out_qsize 4
# 2018-09-17 18:05:13,157 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:13,158 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:13,165 : INFO : EPOCH - 15 : training on 68986 raw words (48800 effective words) took 1.2s, 39121 effective words/s
# 2018-09-17 18:05:14,170 : INFO : EPOCH 16 - PROGRESS: at 79.22% examples, 38872 words/s, in_qsize 2, out_qsize 3
# 2018-09-17 18:05:14,432 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:14,433 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:14,440 : INFO : EPOCH - 16 : training on 68986 raw words (48838 effective words) took 1.3s, 38468 effective words/s
# 2018-09-17 18:05:15,445 : INFO : EPOCH 17 - PROGRESS: at 79.92% examples, 38909 words/s, in_qsize 1, out_qsize 4
# 2018-09-17 18:05:15,706 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:15,711 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:15,714 : INFO : EPOCH - 17 : training on 68986 raw words (48515 effective words) took 1.3s, 38227 effective words/s
# 2018-09-17 18:05:16,727 : INFO : EPOCH 18 - PROGRESS: at 79.33% examples, 38818 words/s, in_qsize 1, out_qsize 3
# 2018-09-17 18:05:16,987 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:16,989 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:16,996 : INFO : EPOCH - 18 : training on 68986 raw words (48755 effective words) took 1.3s, 38397 effective words/s
# 2018-09-17 18:05:18,002 : INFO : EPOCH 19 - PROGRESS: at 77.90% examples, 37993 words/s, in_qsize 1, out_qsize 4
# 2018-09-17 18:05:18,285 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:18,286 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:18,295 : INFO : EPOCH - 19 : training on 68986 raw words (48582 effective words) took 1.3s, 37573 effective words/s
# 2018-09-17 18:05:19,300 : INFO : EPOCH 20 - PROGRESS: at 79.27% examples, 38797 words/s, in_qsize 3, out_qsize 0
# 2018-09-17 18:05:19,566 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-17 18:05:19,567 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-17 18:05:19,571 : INFO : EPOCH - 20 : training on 68986 raw words (48728 effective words) took 1.3s, 38357 effective words/s
# 2018-09-17 18:05:19,574 : INFO : training on a 1379720 raw words (974215 effective words) took 25.7s, 37896 effective words/s

# %% [markdown]
# ## Save the model

# %%
model.save('srt.model')
# Out:
# 2018-09-17 18:05:20,501 : INFO : saving Word2Vec object under srt.model, separately None
# 2018-09-17 18:05:20,503 : INFO : not storing attribute vectors_norm
# 2018-09-17 18:05:20,506 : INFO : not storing attribute cum_table
# 2018-09-17 18:05:20,575 : INFO : saved srt.model

# %% [markdown]
# ## Show most similar words to "man"

# %%
model.wv.most_similar('man')
# Out:
# 2018-09-17 18:05:21,603 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('gasp', 0.9633530974388123),
#  ('cab', 0.9622167348861694),
#  ('luck', 0.9616068601608276),
#  ('wow', 0.9598132371902466),
#  ('abandon', 0.958922266960144),
#  ('avert', 0.9583507180213928),
#  ('such', 0.9546405673027039),
#  ('marshgammon', 0.9544152617454529),
#  ('job', 0.9529415369033813),
#  ('fault', 0.9523583054542542)]

# %% [markdown]
# ## In order to get better results we need a larger dataset : maybe all the subtitles of 2018 TV series.
